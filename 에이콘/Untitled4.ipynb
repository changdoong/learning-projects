# %%
import numpy as np

# %%
print(np.newaxis is None)
X = np.arange(3)
# Out:
# True

# %%
X, X.shape
# Out:
# (array([0, 1, 2]), (3,))

# %%
X[:, np.newaxis, np.newaxis]
X[:, np.newaxis, np.newaxis].shape
# Out:
# (3, 1, 1)

# %%
X[:, np.newaxis] * X
# Out:
# array([[0, 0, 0],
#        [0, 1, 2],
#        [0, 2, 4]])

# %%
X[: np.newaxis, np.newaxis, np.newaxis, np.newaxis].shape
# Out:
# (3, 1, 1, 1)

# %%
pd.rea
