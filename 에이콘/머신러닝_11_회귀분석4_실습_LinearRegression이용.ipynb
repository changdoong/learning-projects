# %%
# 모듈 임포트
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 회귀분석의 목적
#
# |설명모형|예측모형|
# |---|---|
# |전통적인 통계분야로서 데이터가 적은 모형|데이터마이닝 분야로서 데이터가 충분한 모형|
# | ${\hat y} = \beta_1 X + \beta_0 $ 에서 $X$ 에 초점을 둠|  ${\hat y} = \beta_1 X + \beta_0 $ 에서 $\hat y$ 에 초점을 둠|
# |종속(타깃,출력)변수와 독립(피처,예측)변수들간의 관계를 **설명**|새로운 사례에 대해 출력값을 **예측**<br>적합된 모형을 이용하여 알려지지 않은 데이터에 대한 **예측**|
# |모집단에서 가정하는 가설적 관계에 대한 정보를 <br> 최대한 반영할 수 있도록 전체 데이터 집합 사용하여 최상의 적합모형 추정|학습용 데이터세트(모형 추정)와 평가용 데이터세트(모형 성능평가)로 나눔|

# %% [markdown]
# ---

# %% [markdown]
# ## LinearRegression을 이용한 주택 가격 예측

# %% [markdown]
# ### 데이터셋 : House Sales in King County, USA

# %% [markdown]
# - 2014년 5월 ~ 2015년 5월까지 King County 주택가격
# - kc_house_data.csv
# - 출처: https://www.kaggle.com/harlfoxem/housesalesprediction

# %% [markdown]
# ### 데이터 준비

# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')
df.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# [3 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.drop(columns='id').describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_9ed59_row0_col0, #T_9ed59_row1_col1, #T_9ed59_row1_col2, #T_9ed59_row1_col5, #T_9ed59_row1_col6, #T_9ed59_row1_col7, #T_9ed59_row1_col8, #T_9ed59_row1_col9, #T_9ed59_row1_col13, #T_9ed59_row1_col15, #T_9ed59_row1_col16, #T_9ed59_row2_col1, #T_9ed59_row2_col2, #T_9ed59_row2_col5, #T_9ed59_row2_col6, #T_9ed59_row2_col7, #T_9ed59_row2_col8, #T_9ed59_row2_col9, #T_9ed59_row2_col12, #T_9ed59_row2_col14, #T_9ed59_row2_col15, #T_9ed59_row3_col1, #T_9ed59_row3_col2, #T_9ed59_row3_col3, #T_9ed59_row3_col4, #T_9ed59_row3_col5, #T_9ed59_row3_col6, #T_9ed59_row3_col7, #T_9ed59_row3_col8, #T_9ed59_row3_col9, #T_9ed59_row3_col10, #T_9ed59_row3_col11, #T_9ed59_row3_col13, #T_9ed59_row3_col15, #T_9ed59_row3_col16, #T_9ed59_row3_col17, #T_9ed59_row3_col18, #T_9ed59_row4_col1, #T_9ed59_row4_col2, #T_9ed59_row4_col4, #T_9ed59_row4_col5, #T_9ed59_row4_col6, #T_9ed59_row4_col7, #T_9ed59_row4_col8, #T_9ed59_row4_col9, #T_9ed59_row4_col11, #T_9ed59_row4_col13, #T_9ed59_row4_col15, #T_9ed59_row4_col16, #T_9ed59_row5_col1, #T_9ed59_row5_col2, #T
{
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_9ed59_row7_col11 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_9ed59_row7_col17 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# </style>
# <table id="T_9ed59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ed59_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_9ed59_level0_col1" class="col_heading level0 col1" >bedrooms</th>
#       <th id="T_9ed59_level0_col2" class="col_heading level0 col2" >bathrooms</th>
#       <th id="T_9ed59_level0_col3" class="col_heading level0 col3" >sqft_living</th>
#       <th id="T_9ed59_level0_col4" class="col_heading level0 col4" >sqft_lot</th>
#       <th id="T_9ed59_level0_col5" class="col_heading level0 col5" >floors</th>
#       <th id="T_9ed59_level0_col6" class="col_heading level0 col6" >waterfront</th>
#       <th id="T_9ed59_level0_col7" class="col_heading level0 col7" >view</th>
#       <th id="T_9ed59_level0_col8" class="col_heading level0 col8" >condition</th>
#       <th id="T_9ed59_level0_col9" class="col_heading level0 col9" >grade</th>
#       <th id="T_9ed59_level0_col10" class="col_heading level0 col10" >sqft_above</th>
#       <th id="T_9ed59_level0_col11" class="col_heading level0 col11" >sqft_basement</th>
#       <th id="T_9ed59_level0_col12" class="col_heading level0 col12" >yr_built</th>
#       <th id="T_9ed59_level0_col13" class="col_heading level0 col13" >yr_renovated</th>
#       <th id="T_9ed59_level0_col14" class="col_heading level0 col14" >zipcode</th>
#       <th id="T_9ed59_level0_col15" class="col_heading level0 col15" >lat</th>
#       <th id="T_9ed59_level0_col16" class="col_heading level0 col16" >long</th>
#       <th id="T_9ed59_level0_col17" class="col_heading level0 col17" >sqft_living15</th>
#       <th id="T_9ed59_level0_col18" class="col_heading level0 col18" >sqft_lot15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ed59_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_9ed59_row0_col0" class="data row0 col0" >21613.000000</td>
#       <td id="T_9ed59_row0_col1" class="data row0 col1" >21613.000000</td>
#       <td id="T_9ed59_row0_col2" class="data row0 col2" >21613.000000</td>
#       <td id="T_9ed59_row0_col3" class="data row0 col3" >21613.000000</td>
#       <td id="T_9ed59_row0_col4" class="data row0 col4" >21613.000000</td>
#       <td id="T_9ed59_row0_col5" class="data row0 col5" >21613.000000</td>
#       <td id="T_9ed59_row0_col6" class="data row0 col6" >21613.000000</td>
#       <td id="T_9ed59_row0_col7" class="data row0 col7" >21613.000000</td>
#       <td id="T_9ed59_row0_col8" class="data row0 col8" >21613.000000</td>
#       <td id="T_9ed59_row0_col9" class="data row0 col9" >21613.000000</td>
#       <td id="T_9ed59_row0_col10" class="data row0 col10" >21613.000000</td>
#       <td id="T_9ed59_row0_col11" class="data row0 col11" >21613.000000</td>
#       <td id="T_9ed59_row0_col12" class="data row0 col12" >21613.000000</td>
#       <td id="T_9ed59_row0_col13" class="data row0 col13" >21613.000000</td>
#       <td id="T_9ed59_row0_col14" class="data row0 col14" >21613.000000</td>
#       <td id="T_9ed59_row0_col15" class="data row0 col15" >21613.000000</td>
#       <td id="T_9ed59_row0_col16" class="data row0 col16" >21613.000000</td>
#       <td id="T_9ed59_row0_col17" class="data row0 col17" >21613.000000</td>
#       <td id="T_9ed59_row0_col18" class="data row0 col18" >21613.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9ed59_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_9ed59_row1_col0" class="data row1 col0" >540088.141767</td>
#       <td id="T_9ed59_row1_col1" class="data row1 col1" >3.370842</td>
#       <td id="T_9ed59_row1_col2" class="data row1 col2" >2.114757</td>
#       <td id="T

# %% [markdown]
# ### 데이터 탐색 및 전처리

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# #### 데이터 전처리 함수

# %% [markdown]
# #### 변수별 히스토그램

# %% [markdown]
# #### 상관관계 히트맵

# %% [markdown]
# #### 주택가격과 상관관계

# %% [markdown]
# #### 주요 피처와 주택가격과의 관계(산점도, regplot)

# %% [markdown]
# #### 주택가격 예측에 영향이 작은 변수 삭제
#
# - price와 상관관계가 매우 약한(corr<0.2) 변수들
#
# - 'sqft_living'과 상관관계가 강한 변수들
#
# - 'sold-built_years'를 도출한 변수들

# %% [markdown]
# ##### 데이터 변환 함수 수정

# %% [markdown]
# ### 선형 회귀 모델 학습/예측/평가

# %% [markdown]
# #### 회귀 모델의 절편, 회귀계수

# %% [markdown]
# #### 회귀계수를 큰 값 순으로 정렬

# %% [markdown]
# #### 회귀계수 시각화

# %% [markdown]
# #### 회귀계수 출력 및 시각화 함수 작성

# %% [markdown]
# #### 실제값과 예측값과의 차이

# %%
get_residual(y_test, y_pred)

# %% [markdown]
# ### 교차 검증으로 MSE와 RMSE 측정

# %% [markdown]
# cross_val_score() 이용

# %% [markdown]
# -------

# %% [markdown]
# ### 주택가격 price를 로그변환하여 회귀분석 진행

# %% [markdown]
# #### 주택가격 price 분포

# %% [markdown]
# #### 로그변환된 price 분포

# %% [markdown]
# #### 모델 성능 평가 RMSLE(Root Mean Square Log Error)를 위한 함수 작성
#
# - 오류 값의 로그에 대한 RMSE

# %% [markdown]
# #### RMSE 함수 작성

# %% [markdown]
# #### 회귀모델 성능 평가를 위한 함수 작성
#
# - MSE, RMSE, RMSLE, MAE, R2 계산

# %% [markdown]
# #### 로그변환된 주택가격 회귀모델 학습 및 평가

# %% [markdown]
# #### 실제값과 예측값과의 차이

# %% [markdown]
# #### 회귀계수

# %% [markdown]
# #### 회귀모델 학습 및 평가 수치 반환 함수 작성

# %% [markdown]
# ------

# %% [markdown]
# ### 범주형 변수 원한인코딩 후 회귀분석 진행

# %% [markdown]
# #### 범주형 변수 원핫인코딩
#
# - waterfront, view

# %% [markdown]
# #### 로그변환, 원핫인코딩한 데이터로 회귀모델 예측

# %% [markdown]
# #### 회귀계수

# %% [markdown]
# -------------------------------------------------
