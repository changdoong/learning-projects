# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.19.0'

# %%
import sklearn
sklearn.__version__
# Out:
# '1.6.0'

# %% [markdown]
# # 신경망 모델 훈련

# %% [markdown]
# **[핵심키워드]** 손실곡선, 드롭아웃(dropout), 콜백(callback), 조기종료
#
# - 인공신경망 모델을 훈련하는 모범 사례와 필요한 도구 학습

# %%
from tensorflow import keras
from keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 데이터 준비

# %%
(train_input, train_target), (test_input, test_target) = fashion_mnist.load_data()

# %%
train_scaled = train_input/255
test_scaled = test_input/255

X_train, X_val, y_train, y_val = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (48000, 28, 28)

# %%
target_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat',
                'Sandal','Shirt','Sneaker','Bag','Ankle boot']
fig, axs = plt.subplots(figsize=(24,20), nrows=2, ncols=10)
for i in range(20):
    r, c = i//10, i%10
    img, label = X_train[i], y_train[i]
    axs[r][c].imshow(train_input[i], cmap=plt.cm.binary)
    axs[r][c].axis('off')
    axs[r][c].set_title(target_names[label])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 모델 생성 함수 정의
#
# : 함수의 a_layer 매개변수는 케라스 층으로서, 은닉층 뒤에 층을 추가하는 함수

# %%
from keras import Sequential 
from keras.layers import Dense, Input, Flatten

def build_model(a_layer=None):
    model = Sequential()
    model.add(Flatten(input_shape=(28,28)))
    model.add(Dense(100, activation='relu'))
    if a_layer:
        model.add(a_layer)
    model.add(Dense(10, activation='softmax'))
    return model

# %% [markdown]
# ### 모델 생성하고 모델의 정보 출력

# %%
model = build_model()
model.summary()
# Out:
# C:\ProgramData\anaconda3\envs\tensor\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │          78,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 모델 컴파일 및 훈련
# : 훈련된 모델 객체를 변수 history에 저장

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8127 - loss: 0.5299
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8582 - loss: 0.3923
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8725 - loss: 0.3537
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8811 - loss: 0.3298
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8856 - loss: 0.3162

# %% [markdown]
# - history 객체는 딕셔너리 형식으로 훈련 측정값이 저장되어 있음
#     - loss와 accuracy : 에포크마다 계산한 값이 순서대로 리스트에 저장

# %%
history.history['accuracy']
# Out:
# [0.81270831823349,
#  0.8581666946411133,
#  0.8725416660308838,
#  0.8811041712760925,
#  0.8856250047683716]

# %%
history.history['loss']
# Out:
# [0.5299496054649353,
#  0.3922818601131439,
#  0.3537144362926483,
#  0.32978034019470215,
#  0.31623464822769165]

# %% [markdown]
# ## 손실 곡선

# %% [markdown]
# ### history 속성에 포함된 손실(loss)과 정확도(accuracy) 시각화

# %%
def draw_loss_metric_plot(history):
    plt.figure(figsize=(10,5))
    for i, item in enumerate(history. history.keys()):
        plt.subplot(1,2,i+1)
        n = len(history.history[item])
        plt.plot(range(1, n+1), history.history[item], label=item)
        plt.xlabel('epoch')
        plt.ylabel(item)
        plt.title(f'{item} plot')
        plt.legend()
    plt.show()

# %%
draw_loss_metric_plot(history)

# %%
print('epoch=5일때')
for item in history.history.keys():
    print(f'{item}:{history.history[item][-1]:.4f}', end=' ')
print()
# Out:
# epoch=5일때
# accuracy:0.8856 loss:0.3162

# %% [markdown]
# ### epochs=20 인 경우 모델 훈련 후 loss 값 시각화

# %%
model2 = build_model()
model2.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history2 = model2.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8151 - loss: 0.5329
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8590 - loss: 0.3905
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8714 - loss: 0.3535
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8807 - loss: 0.3318
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8855 - loss: 0.3162
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8918 - loss: 0.3055
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8947 - loss: 0.2960
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8977 - loss: 0.2867
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9015 - loss: 0.2788
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9034 - loss: 0.2720
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9060 - loss: 0.2677
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9078 - loss: 0.2630
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9112 - loss: 0.2553
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9123 - loss: 0.2526
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9147 - loss: 0.2474
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9154 - loss: 0.2428
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9187 - loss: 0.2388
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9189 - loss: 0.2361
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9195 - loss: 0.2305
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9201 - loss: 0.2274

# %%
draw_loss_metric_plot(history2)
print('epoch=20일때')
for item in history.history.keys():
    print(f'{item}:{history.history[item][-1]:.4f}', end=' ')
print()
# Out:
# epoch=20일때
# accuracy:0.8856 loss:0.3162

# %% [markdown]
# #### [문제1] epochs=40으로 학습한 경우 accuracy, loss값을 그래프로 그려보시오

# %%
model3 = build_model()
model3.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history3 = model3.fit(X_train, y_train, epochs=40)
# Out:
# Epoch 1/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8109 - loss: 0.5361
# Epoch 2/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8581 - loss: 0.3926
# Epoch 3/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8723 - loss: 0.3556
# Epoch 4/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8808 - loss: 0.3327
# Epoch 5/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8871 - loss: 0.3168
# Epoch 6/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8907 - loss: 0.3065
# Epoch 7/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8952 - loss: 0.2954
# Epoch 8/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8962 - loss: 0.2887
# Epoch 9/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9012 - loss: 0.2792
# Epoch 10/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9034 - loss: 0.2727
# Epoch 11/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9050 - loss: 0.2673
# Epoch 12/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9088 - loss: 0.2615
# Epoch 13/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9107 - loss: 0.2531
# Epoch 14/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9114 - loss: 0.2497
# Epoch 15/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9134 - loss: 0.2461
# Epoch 16/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9153 - loss: 0.2413
# Epoch 17/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9167 - loss: 0.2371
# Epoch 18/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9190 - loss: 0.2343
# Epoch 19/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9209 - loss: 0.2273
# Epoch 20/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9219 - loss: 0.2263
# Epoch 21/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9237 - loss: 0.2195
# Epoch 22/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9260 - loss: 0.2171
# Epoch 23/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9257 - loss: 0.2145
# Epoch 24/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9281 - loss: 0.2125
# Epoch 25/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9293 - loss: 0.2077
# Epoch 26/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9301 - loss: 0.2057
# Epoch 27/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9317 - loss: 0.2021
# Epoch 28/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9319 - loss: 0.1993
# Epoch 29/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9320 - loss: 0.1999
# Epoch 30/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9349 - loss: 0.1921
# Epoch 31/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9343 - loss: 0.1940
# Epoch 32/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9361 - loss: 0.1866
# Epoch 33/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9373 - loss: 0.1856
# Epoch 34/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9385 - loss: 0.1841
# Epoch 35/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9401 - loss: 0.1808
# Epoch 36/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9409 - loss: 0.1816
# Epoch 37/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9413 - loss: 0.1809
# Epoch 38/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9431 - loss: 0.1722
# Epoch 39/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9414 - loss: 0.1721
# Epoch 40/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9444 - loss: 0.1670

# %%
draw_loss_metric_plot(history3)
print('epoch=40일때')
for item in history.history.keys():
    print(f'{item}:{history.history[item][-1]:.4f}', end=' ')
print()
# Out:
# epoch=40일때
# accuracy:0.8856 loss:0.3162

# %% [markdown]
# ## 검증 손실

# %% [markdown]
# - 에포크에 따라 과대적합과 과소적합이 달라짐
# - 인공신경망 모델이 최적화하는 대상을 정확도가 아니라 손실함수
#     - 손실감소에 비례하여 정확도가 높아지지 않는 경우도 있음
#     - 모델이 잘 훈련되었는지 판단하기 위해서는 정확도보다는 손실함수의 값을 확인

# %% [markdown]
# #### 에포크마다 검증 손실 계산
# - fit() 메서드의 **validation_data** 매개변수에 검증 데이터를 전달
# - 검증할 입력과 타깃값은 튜플로 전달

# %% [markdown]
# #### 검증데이터에 대한 손실과 정확도는 val_loss, val_accuracy에 저장

# %%
def draw_loss_val_plot(history):
    acc = ['accuracy', 'val_accuracy']
    loss = ['loss', 'val_loss']
    title = ['Loss', 'Accuracy']
    plt.figure(figsize=(10,5))
    for i, item in enumerate([loss, acc]):
        plt.subplot(1,2,i+1)
        n = len(history.history[item[0]])
        plt.plot(range(1, n+1), history.history[item[0]], label=item[0])
        plt.plot(range(1, n+1), history.history[item[1]], label=item[1])
        
        plt.xlabel('epoch')
        plt.ylabel(title[i])
        plt.title(f'{title[i]} plot')
        plt.legend()
    plt.show()

# %% [markdown]
# #### 훈련데이터와 검증데이터에 대한 손실과 정확도 시각화

# %%
model4 = build_model()
model4.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history4 = model4.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8121 - loss: 0.5298 - val_accuracy: 0.8522 - val_loss: 0.4086
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8592 - loss: 0.3903 - val_accuracy: 0.8506 - val_loss: 0.4051
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8715 - loss: 0.3533 - val_accuracy: 0.8679 - val_loss: 0.3730
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8808 - loss: 0.3325 - val_accuracy: 0.8773 - val_loss: 0.3458
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8858 - loss: 0.3173 - val_accuracy: 0.8762 - val_loss: 0.3588
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8901 - loss: 0.3051 - val_accuracy: 0.8807 - val_loss: 0.3524
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8934 - loss: 0.2945 - val_accuracy: 0.8668 - val_loss: 0.4048
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8991 - loss: 0.2868 - val_accuracy: 0.8773 - val_loss: 0.3625
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8998 - loss: 0.2795 - val_accuracy: 0.8793 - val_loss: 0.3815
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9029 - loss: 0.2741 - val_accuracy: 0.8823 - val_loss: 0.3751
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9056 - loss: 0.2674 - val_accuracy: 0.8738 - val_loss: 0.4157
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9066 - loss: 0.2627 - val_accuracy: 0.8826 - val_loss: 0.3781
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9084 - loss: 0.2559 - val_accuracy: 0.8795 - val_loss: 0.3979
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9113 - loss: 0.2521 - val_accuracy: 0.8832 - val_loss: 0.3887
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9147 - loss: 0.2460 - val_accuracy: 0.8798 - val_loss: 0.4015
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9151 - loss: 0.2425 - val_accuracy: 0.8859 - val_loss: 0.3947
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9180 - loss: 0.2371 - val_accuracy: 0.8846 - val_loss: 0.4040
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9205 - loss: 0.2326 - val_accuracy: 0.8849 - val_loss: 0.4054
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9223 - loss: 0.2293 - val_accuracy: 0.8872 - val_loss: 0.4053
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9226 - loss: 0.2271 - val_accuracy: 0.8770 - val_loss: 0.4507

# %%
draw_loss_val_plot(history4)
print('epoch=20일때')
for item in history4.history.keys():
    print(f'{item}:{history4.history[item][-1]:.4f}', end=' ')
print()
# Out:
# epoch=20일때
# accuracy:0.9226 loss:0.2271 val_accuracy:0.8770 val_loss:0.4507

# %% [markdown]
# #### Adam 옵티마이저를 이용한 모델의 훈련 손실과 검증 손실

# %%
model5 = build_model()
model5.compile(optimizer='adam',
               loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history5 = model5.fit(X_train, y_train, epochs=20, verbose=0, validation_data=(X_val, y_val))

# %%
draw_loss_val_plot(history5)
print('optimizer="adam", epoch=20일때')
for item in history5.history.keys():
    print(f'{item}:{history5.history[item][-1]:.4f}', end=' ')
print()
# Out:
# optimizer="adam", epoch=20일때
# accuracy:0.9300 loss:0.1866 val_accuracy:0.8832 val_loss:0.3577

# %% [markdown]
# [결과]
# - Adam옵티마이져가 RMSprop 옵티마이져보다 과대적합이 많이 줄어듬
# - 검증손실 및 정확도는 14번째 에포크까지 감소하다가 다시 늘어남

# %%
def fmnist_modeling(X_train, y_train, X_val, y_val, optimizer='rmsprop', epochs=20):
    model = build_model()
    model.compile(optimizer=optimizer,
                   loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_val, y_val))
    print(f'optimizer={optimizer}, epochs={epochs}일때')
    for item in history.history.keys():
        print(f'{item}:{history.history[item][-1]:.4f}', end=' ')
    print()
    draw_loss_val_plot(history)
    return model

# %%
fmnist_modeling(X_train, y_train, X_val, y_val, optimizer='rmsprop', epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8118 - loss: 0.5340 - val_accuracy: 0.8599 - val_loss: 0.4039
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8572 - loss: 0.3939 - val_accuracy: 0.8541 - val_loss: 0.4164
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8728 - loss: 0.3562 - val_accuracy: 0.8689 - val_loss: 0.3695
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8805 - loss: 0.3304 - val_accuracy: 0.8768 - val_loss: 0.3534
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8871 - loss: 0.3172 - val_accuracy: 0.8785 - val_loss: 0.3577
# optimizer=rmsprop, epochs=5일때
# accuracy:0.8871 loss:0.3172 val_accuracy:0.8785 val_loss:0.3577
# <Sequential name=sequential_5, built=True>

# %% [markdown]
# #### [문제2] 앞의 신경망 모델에 대하여 학습률을 조정하여 변화되는 손실 곡선을 그려보시오.

# %% [markdown]
# - RMSprop(learning_rate=0.05)인 경우

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=0.0005)
fmnist_modeling(X_train, y_train, X_val, y_val, optimizer=rmsprop, epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8093 - loss: 0.5497 - val_accuracy: 0.8397 - val_loss: 0.4701
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8531 - loss: 0.4123 - val_accuracy: 0.8547 - val_loss: 0.4026
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8679 - loss: 0.3715 - val_accuracy: 0.8679 - val_loss: 0.3743
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8755 - loss: 0.3482 - val_accuracy: 0.8644 - val_loss: 0.3868
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8812 - loss: 0.3287 - val_accuracy: 0.8722 - val_loss: 0.3582
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8864 - loss: 0.3141 - val_accuracy: 0.8738 - val_loss: 0.3582
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8904 - loss: 0.3013 - val_accuracy: 0.8772 - val_loss: 0.3475
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8954 - loss: 0.2921 - val_accuracy: 0.8762 - val_loss: 0.3545
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8988 - loss: 0.2834 - val_accuracy: 0.8798 - val_loss: 0.3456
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9019 - loss: 0.2746 - val_accuracy: 0.8863 - val_loss: 0.3354
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9041 - loss: 0.2668 - val_accuracy: 0.8809 - val_loss: 0.3498
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9066 - loss: 0.2609 - val_accuracy: 0.8873 - val_loss: 0.3322
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9088 - loss: 0.2532 - val_accuracy: 0.8862 - val_loss: 0.3441
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9111 - loss: 0.2502 - val_accuracy: 0.8887 - val_loss: 0.3290
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9131 - loss: 0.2433 - val_accuracy: 0.8859 - val_loss: 0.3422
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9176 - loss: 0.2351 - val_accuracy: 0.8827 - val_loss: 0.3494
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9170 - loss: 0.2330 - val_accuracy: 0.8834 - val_loss: 0.3504
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9197 - loss: 0.2271 - val_accuracy: 0.8852 - val_loss: 0.3622
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9195 - loss: 0.2225 - val_accuracy: 0.8859 - val_loss: 0.3527
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9231 - loss: 0.2193 - val_accuracy: 0.8871 - val_loss: 0.3468
# optimizer=<keras.src.optimizers.rmsprop.RMSprop object at 0x000002CC9CF7DE80>, epochs=20일때
# accuracy:0.9231 loss:0.2193 val_accuracy:0.8871 val_loss:0.3468
# <Sequential name=sequential_6, built=True>

# %% [markdown]
# - Adam(learning_rate=0.0005)

# %%
adam = keras.optimizers.Adam(learning_rate=0.0005)
fmnist_modeling(X_train, y_train, X_val, y_val, optimizer=adam, epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8081 - loss: 0.5651 - val_accuracy: 0.8338 - val_loss: 0.4687
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8530 - loss: 0.4177 - val_accuracy: 0.8631 - val_loss: 0.3951
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8668 - loss: 0.3752 - val_accuracy: 0.8699 - val_loss: 0.3681
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8768 - loss: 0.3475 - val_accuracy: 0.8715 - val_loss: 0.3576
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8817 - loss: 0.3278 - val_accuracy: 0.8714 - val_loss: 0.3570
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8871 - loss: 0.3134 - val_accuracy: 0.8755 - val_loss: 0.3451
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8913 - loss: 0.2985 - val_accuracy: 0.8757 - val_loss: 0.3500
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8950 - loss: 0.2856 - val_accuracy: 0.8743 - val_loss: 0.3461
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8988 - loss: 0.2759 - val_accuracy: 0.8825 - val_loss: 0.3278
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9025 - loss: 0.2654 - val_accuracy: 0.8822 - val_loss: 0.3227
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9044 - loss: 0.2590 - val_accuracy: 0.8829 - val_loss: 0.3270
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9087 - loss: 0.2503 - val_accuracy: 0.8888 - val_loss: 0.3070
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9113 - loss: 0.2417 - val_accuracy: 0.8859 - val_loss: 0.3193
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9140 - loss: 0.2341 - val_accuracy: 0.8892 - val_loss: 0.3087
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9162 - loss: 0.2281 - val_accuracy: 0.8851 - val_loss: 0.3275
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9188 - loss: 0.2227 - val_accuracy: 0.8907 - val_loss: 0.3141
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9199 - loss: 0.2159 - val_accuracy: 0.8904 - val_loss: 0.3129
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9222 - loss: 0.2100 - val_accuracy: 0.8827 - val_loss: 0.3363
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9234 - loss: 0.2068 - val_accuracy: 0.8874 - val_loss: 0.3200
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9262 - loss: 0.2006 - val_accuracy: 0.8912 - val_loss: 0.3167
# optimizer=<keras.src.optimizers.adam.Adam object at 0x000002CC9CC1C4A0>, epochs=20일때
# accuracy:0.9262 loss:0.2006 val_accuracy:0.8912 val_loss:0.3167
# <Sequential name=sequential_7, built=True>

# %% [markdown]
# => 옵티마이저의 학습률(learning_rate)의 크기가 모델의 성능에 영향을 줌

# %% [markdown]
# - Adam(learning_rate=0.0005) & epochs=40

# %%
adam = keras.optimizers.Adam(learning_rate=0.0005)
fmnist_modeling(X_train, y_train, X_val, y_val, optimizer=adam, epochs=40)
# Out:
# Epoch 1/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8044 - loss: 0.5744 - val_accuracy: 0.8389 - val_loss: 0.4575
# Epoch 2/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8517 - loss: 0.4235 - val_accuracy: 0.8571 - val_loss: 0.4005
# Epoch 3/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8635 - loss: 0.3837 - val_accuracy: 0.8572 - val_loss: 0.4099
# Epoch 4/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8741 - loss: 0.3557 - val_accuracy: 0.8670 - val_loss: 0.3866
# Epoch 5/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8806 - loss: 0.3324 - val_accuracy: 0.8788 - val_loss: 0.3458
# Epoch 6/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8857 - loss: 0.3165 - val_accuracy: 0.8685 - val_loss: 0.3606
# Epoch 7/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8924 - loss: 0.3009 - val_accuracy: 0.8752 - val_loss: 0.3519
# Epoch 8/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8946 - loss: 0.2892 - val_accuracy: 0.8824 - val_loss: 0.3230
# Epoch 9/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8986 - loss: 0.2779 - val_accuracy: 0.8841 - val_loss: 0.3265
# Epoch 10/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9012 - loss: 0.2684 - val_accuracy: 0.8719 - val_loss: 0.3503
# Epoch 11/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9056 - loss: 0.2594 - val_accuracy: 0.8827 - val_loss: 0.3246
# Epoch 12/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9068 - loss: 0.2548 - val_accuracy: 0.8873 - val_loss: 0.3155
# Epoch 13/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9100 - loss: 0.2454 - val_accuracy: 0.8870 - val_loss: 0.3161
# Epoch 14/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9135 - loss: 0.2389 - val_accuracy: 0.8854 - val_loss: 0.3224
# Epoch 15/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9147 - loss: 0.2334 - val_accuracy: 0.8849 - val_loss: 0.3290
# Epoch 16/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9173 - loss: 0.2272 - val_accuracy: 0.8895 - val_loss: 0.3173
# Epoch 17/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9192 - loss: 0.2219 - val_accuracy: 0.8892 - val_loss: 0.3154
# Epoch 18/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9212 - loss: 0.2157 - val_accuracy: 0.8848 - val_loss: 0.3316
# Epoch 19/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9226 - loss: 0.2106 - val_accuracy: 0.8843 - val_loss: 0.3228
# Epoch 20/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9243 - loss: 0.2050 - val_accuracy: 0.8881 - val_loss: 0.3204
# Epoch 21/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9262 - loss: 0.1998 - val_accuracy: 0.8873 - val_loss: 0.3201
# Epoch 22/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9283 - loss: 0.1963 - val_accuracy: 0.8883 - val_loss: 0.3246
# Epoch 23/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9295 - loss: 0.1912 - val_accuracy: 0.8908 - val_loss: 0.3264
# Epoch 24/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9327 - loss: 0.1862 - val_accuracy: 0.8898 - val_loss: 0.3190
# Epoch 25/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9326 - loss: 0.1835 - val_accuracy: 0.8905 - val_loss: 0.3297
# Epoch 26/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9346 - loss: 0.1802 - val_accuracy: 0.8908 - val_loss: 0.3246
# Epoch 27/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9352 - loss: 0.1768 - val_accuracy: 0.8854 - val_loss: 0.3508
# Epoch 28/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9373 - loss: 0.1728 - val_accuracy: 0.8912 - val_loss: 0.3356
# Epoch 29/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9379 - loss: 0.1676 - val_accuracy: 0.8884 - val_loss: 0.3403
# Epoch 30/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9400 - loss: 0.1659 - val_accuracy: 0.8898 - val_loss: 0.3372
# Epoch 31/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9409 - loss: 0.1625 - val_accuracy: 0.8922 - val_loss: 0.3310
# Epoch 32/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9424 - loss: 0.1578 - val_accuracy: 0.8907 - val_loss: 0.3425
# Epoch 33/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9428 - loss: 0.1559 - val_accuracy: 0.8892 - val_loss: 0.3525
# Epoch 34/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9442 - loss: 0.1532 - val_accuracy: 0.8888 - val_loss: 0.3445
# Epoch 35/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9454 - loss: 0.1503 - val_accuracy: 0.8923 - val_loss: 0.3448
# Epoch 36/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9453 - loss: 0.1481 - val_accuracy: 0.8934 - val_loss: 0.3583
# Epoch 37/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9484 - loss: 0.1437 - val_accuracy: 0.8909 - val_loss: 0.3586
# Epoch 38/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9487 - loss: 0.1411 - val_accuracy: 0.8882 - val_loss: 0.3655
# Epoch 39/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9490 - loss: 0.1374 - val_accuracy: 0.8904 - val_loss: 0.3662
# Epoch 40/40
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9496 - loss: 0.1360 - val_accuracy: 0.8865 - val_loss: 0.3749
# optimizer=<keras.src.optimizers.adam.Adam object at 0x000002CCA0E83DA0>, epochs=40일때
# accuracy:0.9496 loss:0.1360 val_accuracy:0.8865 val_loss:0.3749
# <Sequential name=sequential_8, built=True>

# %% [markdown]
# ---

# %% [markdown]
# ## 드롭아웃(dropout)
#
# : 딥러닝의 아버지로 불리는 제프리 힌턴(Geoffrey  Hinton)이 소개한 개념
# - 은닉층에서 있는 뉴런의 출력을 랜덤하게 꺼서 과대적합을 막는 기법
# - 훈련 중에 적용되며 평가나 예측에서는 적용되지 않음
# - 텐서플로는 이를 자동으로 처리
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 드롭아웃이 과대적합을 막는 이유?
#
# - 이전 층의 일부 뉴런이 랜덤하게 꺼지면 특정 뉴런에 과대하게 의존하는 것을 줄일 수 있고, 모든 입력에 대해 주의를 기울여야 함

# %% [markdown]
# #### Dropout 클래스
#
# - keras.layres 패키지 아래 제공
#     - keras.layers.Dropout(드롭아웃비율)
#     - 드롭아웃하지 않는 뉴런의 출력은 $1/(1-r)$ 만큼 증가시켜 출력의 총합이 같도록 만듬
#
# - 어떤 층의 뒤에 드롭아웃을 두어 이 층의 출력을 랜덤하게 0으로 만듬

# %%
# 30% 정도 드롭아웃
drop = keras.layers.Dropout(0.3)
model = build_model(drop)
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_9 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 100)                 │          78,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - 은닉층 뒤에 추가된 드롭아웃층은 훈련되는 모델 파라미터가 없고, 드롭아웃비율만 있음
# - 드롭아웃 층이 입력과 출력의 크기가 같음
# - 일부 뉴런의 출력을 0으로 만들지만 전체 출력의 배열의 크기는 바꾸지 않음
# - 훈련이 끝난 뒤에 평가나 예측을 수행할 때는 드롭아웃을 적용하지 말아야 함
# - 텐서플로(케라스)는 모델평가와 예측에서는 자동으로 드롭아웃을 적용하지 않음

# %% [markdown]
# #### 드롭아웃이 적용된 모델의 훈련 손실과 검증 손실 그래프

# %%
def fmnist_modeling(X_train, y_train, X_val, y_val, optimizer='rmsprop', epochs=20, dropout=None):
    if dropout is not None:
        drop_layer = keras.layers.Dropout(dropout)
        model = build_model(drop_layer)
    else:
        model = build_model()
    model.compile(optimizer=optimizer,
                   loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_val, y_val))
    print(f'optimizer={optimizer}, epochs={epochs}일때')
    for item in history.history.keys():
        print(f'{item}:{history.history[item][-1]:.4f}', end=' ')
    print()
    draw_loss_val_plot(history)
    return model

# %%
adam = keras.optimizers.Adam(learning_rate=0.001)
print('Dropout=0.3 적용')
fmnist_modeling(X_train, y_train, X_val, y_val, optimizer=adam, epochs=20, dropout=0.3)
# Out:
# Dropout=0.3 적용
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7950 - loss: 0.5824 - val_accuracy: 0.8472 - val_loss: 0.4234
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8418 - loss: 0.4384 - val_accuracy: 0.8544 - val_loss: 0.3892
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8542 - loss: 0.4026 - val_accuracy: 0.8692 - val_loss: 0.3622
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8608 - loss: 0.3811 - val_accuracy: 0.8716 - val_loss: 0.3553
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8650 - loss: 0.3674 - val_accuracy: 0.8755 - val_loss: 0.3459
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8701 - loss: 0.3520 - val_accuracy: 0.8766 - val_loss: 0.3373
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8733 - loss: 0.3423 - val_accuracy: 0.8770 - val_loss: 0.3382
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8765 - loss: 0.3322 - val_accuracy: 0.8717 - val_loss: 0.3549
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8799 - loss: 0.3261 - val_accuracy: 0.8819 - val_loss: 0.3215
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8818 - loss: 0.3195 - val_accuracy: 0.8774 - val_loss: 0.3360
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8838 - loss: 0.3116 - val_accuracy: 0.8789 - val_loss: 0.3355
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8867 - loss: 0.3064 - val_accuracy: 0.8776 - val_loss: 0.3326
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8878 - loss: 0.3031 - val_accuracy: 0.8864 - val_loss: 0.3149
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8905 - loss: 0.2947 - val_accuracy: 0.8848 - val_loss: 0.3202
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8887 - loss: 0.2949 - val_accuracy: 0.8860 - val_loss: 0.3195
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8939 - loss: 0.2845 - val_accuracy: 0.8858 - val_loss: 0.3178
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8935 - loss: 0.2817 - val_accuracy: 0.8842 - val_loss: 0.3268
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8959 - loss: 0.2777 - val_accuracy: 0.8856 - val_loss: 0.3231
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8951 - loss: 0.2781 - val_accuracy: 0.8785 - val_loss: 0.3356
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8965 - loss: 0.2729 - val_accuracy: 0.8860 - val_loss: 0.3157
# optimizer=<keras.src.optimizers.adam.Adam object at 0x000002CC9EDC2600>, epochs=20일때
# accuracy:0.8965 loss:0.2729 val_accuracy:0.8860 val_loss:0.3157
# <Sequential name=sequential_10, built=True>

# %% [markdown]
# => 드롭아웃 층을 넣으므로써 과적합을 줄이는 효과가 있음

# %% [markdown]
# 딥러닝에서 드롭아웃은 **과적합을 방지**하고, 모델의 **일반화 성능 향상**을 위한 강력한 정규화(Regularization) 기법
# - 무작위 뉴런(유닛) 비활성화 : 은닉층에 있는 일부 뉴런을 일정 확률로 무작위로 선택하여 제거(비활성화)함. 제거된 뉴런과 연결된 모든 가중치로 함께 제거됨
# - 특정 뉴런의존 방지 효과 : 특정 뉴런이나 경로(network)에 지나치게 의존하여 학습 데이터의 특정 패턴에만 맞춰지는 현상(과적합)을 방지
# - 매 학습단계마다 은닉층의 뉴런(유닛)이 다르게 선택되므로 다양한 신경망 구조들을 이용하는 앙상블 학습효과를 얻을 수 있음

# %% [markdown]
# ## 모델 저장과 복원

# %% [markdown]
# #### 에포크 횟수를 10으로 지정하고 모델을 훈련

# %%
adam = keras.optimizers.Adam(learning_rate=0.001)
print('Dropout=0.3 적용')
model = fmnist_modeling(X_train, y_train, X_val, y_val, optimizer=adam, epochs=20, dropout=0.3)
# Out:
# Dropout=0.3 적용
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7905 - loss: 0.5921 - val_accuracy: 0.8408 - val_loss: 0.4356
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8420 - loss: 0.4378 - val_accuracy: 0.8612 - val_loss: 0.3804
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8532 - loss: 0.4053 - val_accuracy: 0.8639 - val_loss: 0.3666
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8611 - loss: 0.3817 - val_accuracy: 0.8698 - val_loss: 0.3565
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8676 - loss: 0.3661 - val_accuracy: 0.8720 - val_loss: 0.3454
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8710 - loss: 0.3530 - val_accuracy: 0.8737 - val_loss: 0.3420
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8736 - loss: 0.3428 - val_accuracy: 0.8725 - val_loss: 0.3454
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8764 - loss: 0.3369 - val_accuracy: 0.8766 - val_loss: 0.3392
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8785 - loss: 0.3259 - val_accuracy: 0.8795 - val_loss: 0.3298
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8802 - loss: 0.3216 - val_accuracy: 0.8809 - val_loss: 0.3262
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8831 - loss: 0.3149 - val_accuracy: 0.8832 - val_loss: 0.3266
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8846 - loss: 0.3090 - val_accuracy: 0.8813 - val_loss: 0.3288
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8856 - loss: 0.3044 - val_accuracy: 0.8839 - val_loss: 0.3193
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8899 - loss: 0.2953 - val_accuracy: 0.8849 - val_loss: 0.3222
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8895 - loss: 0.2949 - val_accuracy: 0.8845 - val_loss: 0.3251
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8917 - loss: 0.2887 - val_accuracy: 0.8867 - val_loss: 0.3268
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8925 - loss: 0.2877 - val_accuracy: 0.8875 - val_loss: 0.3222
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8952 - loss: 0.2810 - val_accuracy: 0.8853 - val_loss: 0.3221
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8953 - loss: 0.2750 - val_accuracy: 0.8866 - val_loss: 0.3299
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8979 - loss: 0.2739 - val_accuracy: 0.8892 - val_loss: 0.3211
# optimizer=<keras.src.optimizers.adam.Adam object at 0x000002CC56FAD580>, epochs=20일때
# accuracy:0.8979 loss:0.2739 val_accuracy:0.8892 val_loss:0.3211

# %% [markdown]
# #### 훈련된 모델의 파라미터를 저장 : save_weights() 메서드
# - 텐서플로의 체크포인트 포맷 또는 HDF5 포맷인 .h5 파일로 저장

# %%
model_path = 'model/'
model.save_weights(model_path+'model.weights.h5')

# %% [markdown]
# #### 훈련된 모델 구조와 파라미터를 함께 저장 : model.save() 메서드
#
# - 텐서플로의 SavedModel 포맷 또는 HDF5 포맷인 .h5 파일로 저장, 권장은 .keras로 저장할 것 권장

# %%
model.save(model_path+'model_whole.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save(model_path+'model_whole.keras')

# %% [markdown]
# #### 저장된 파일들 확인

# %%
# %cd model
# %ls
# %cd ..
# %ls
# Out:
# C:\Users\user\model
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 141E-601F
#
#  C:\Users\user\model 디렉터리
#
# 2025-11-05  오전 11:53    <DIR>          .
# 2025-11-05  오전 11:52    <DIR>          ..
# 2025-11-05  오전 11:53           976,600 model.weights.h5
# 2025-11-05  오전 11:53           978,584 model_whole.h5
# 2025-11-05  오전 11:53           978,955 model_whole.keras
#                3개 파일           2,934,139 바이트
#                2개 디렉터리  46,086,381,568 바이트 남음
# C:\Users\user
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 141E-601F
#
#  C:\Users\user 디렉터리
#
# 2025-11-05  오전 11:52    <DIR>          .
# 2025-07-02  오전 08:08    <DIR>          ..
# 2025-07-22  오전 09:28    <DIR>          .anaconda
# 2025-09-29  오전 09:28    <DIR>          .cache
# 2025-09-05  오후 02:37    <DIR>          .conda
# 2025-07-22  오전 09:28                25 .condarc
# 2025-07-22  오전 09:28    <DIR>          .continuum
# 2025-09-09  오전 10:17                53 .gitconfig
# 2025-07-23  오전 08:46    <DIR>          .idlerc
# 2025-11-04  오후 04:22    <DIR>          .ipynb_checkpoints
# 2025-07-22  오후 03:41    <DIR>          .ipython
# 2025-09-09  오전 10:22    <DIR>          .jupyter
# 2025-11-03  오후 04:50    <DIR>          .keras
# 2025-07-23  오전 11:43    <DIR>          .matplotlib
# 2025-08-27  오후 03:41    <DIR>          .ssh
# 2025-09-05  오후 03:20    <DIR>          .streamlit
# 2025-08-29  오후 01:38    <DIR>          .VirtualBox
# 2025-09-01  오전 10:37    <DIR>          .vscode
# 2025-09-03  오전 11:27    <DIR>          .wdm
# 2025-09-22  오전 09:48           109,769 06.quiz_questions.ipynb
# 2025-07-15  오후 02:06                31 afiedt.buf
# 2025-07-22  오전 10:25    <DIR>          anaconda_projects
# 2025-10-28  오전 11:07            35,203 boston.csv
# 2025-07-01  오후 02:58    <DIR>          Contacts
# 2025-09-30  오전 10:19           129,339 crocodile_df.ipynb
# 2025-10-31  오후 02:40    <DIR>          Desktop
# 2025-10-20  오후 05:20            23,873 diabetes.csv
# 2025-08-28  오전 09:49    <DIR>          Documents
# 2025-11-05  오전 09:16    <DIR>          Downloads
# 2025-07-01  오후 02:58    <DIR>          Favorites
# 2025-10-20  오전 11:38             1,325 fname
# 2025-10-29  오후 03:33         3,000,128 fruits_300.npy
# 2025-07-07  오후 01:29             6,438 hr_user.sql
# 2025-07-07  오후 01:29             1,332 hr_user1.sql
# 2025-10-27  오전 10:15         2,515,206 kc_house_data.csv
# 2025-10-17  오전 09:20    <DIR>          learning-projects
# 2025-10-15  오후 05:48    <DIR>          lifesat
# 2025-07-01  오후 02:58    <DIR>          Links
# 2025-07-16  오후 05:49                 0 LKDM_USER.sql
# 2025-10-13  오후 04:02             6,009 log_push.csv
# 2025-09-18  오후 06:07            44,411 machine_learning_quiz-250918.zip
# 2025-09-12  오후 03:04    <DIR>          miniprojects
# 2025-08-21  오후 03:40                 0 mkdir
# 2025-11-05  오전 11:53    <DIR>          model
# 2025-11-04  오후 12:03            20,809 model.png
# 2025-07-01  오후 02:58    <DIR>          Music
# 2025-07-23  오전 08:45    <DIR>          my_python
# 2025-10-29  오전 11:07    <DIR>          mymodule
# 2025-08-25  오후 05:47                 0 name_server.sql
# 2025-07-04  오후 05:56    <DIR>          none
# 2025-07-04  오후 05:56             1,006 none.dmd
# 2025-07-01  오후 03:01    <DIR>          OneDrive
# 2025-10-31  오후 02:40        23,715,344 Online Retail.xlsx
# 2025-07-02  오후 12:23    <DIR>          Oracle
# 2025-10-20  오후 03:16    <DIR>          output
# 2025-07-17  오후 05:22    <DIR>          Pictures
# 2025-09-18  오후 06:11               186 QuizData.csv
# 2025-07-01  오후 02:58    <DIR>          Saved Games
# 2025-07-02  오후 05:58               526 scott_User.sql
# 2025-07-07  오후 01:29             2,447 scott_User1.sql
# 2025-07-07  오후 01:29               578 scott_User2.sql
# 2025-07-03  오전 08:32    <DIR>          Searches
# 2025-08-25  오후 05:47             2,520 source_server.sql
# 2025-10-17  오전 09:31    <DIR>          titanic
# 2025-10-20  오후 04:34             2,608 titanicPreprocess.py
# 2025-10-21  오후 02:27             2,608 titanicPreprocess-Copy1.py
# 2025-08-12  오전 10:17               185 totalmines.ini
# 2025-09-18  오후 06:08               628 Untitled.ipynb
# 2025-10-01  오전 11:13             1,835 Untitled1.ipynb
# 2025-10-13  오후 04:29             8,452 Untitled2.ipynb
# 2025-10-22  오전 10:38            54,703 Untitled3.ipynb
# 2025-10-28  오전 11:05             2,784 Untitled4.ipynb
# 2025-07-02  오후 01:55    <DIR>          Videos
# 2025-08-19  오전 09:59    <DIR>          VirtualBox VMs
# 2025-11-03  오후 03:08         1,222,198 딥러닝01_2_딥러닝과 퍼셉트론_실습.ipynb
# 2025-11-03  오후 05:09           939,671 딥러닝02_1_데이터표현과 텐서연산.ipynb
# 2025-11-04  오전 10:46           142,807 딥러닝02_2_텐서플로와케라스.ipynb
# 2025-11-04  오후 12:50           581,296 딥러닝03_첫번째신경망DNN.ipynb
# 2025-11-05  오전 09:16           426,440 딥러닝04_신경망모델훈련 (1).ipynb
# 2025-11-05  오전 11:52         1,013,937 딥러닝04_신경망모델훈련 (4).ipynb
# 2025-11-05  오전 11:34         1,168,399 딥러닝04_신경망모델훈련.ipynb
# 2025-11-04  오후 04:22           135,274 딥러닝07_케라스모델구축방법.ipynb
# 2025-10-20  오후 05:31           593,509 머신러닝 08_결정트리4_연습문제.ipynb
# 2025-10-14  오후 04:08           591,930 머신러닝_01_실습1_생선분류1.ipynb
# 2025-10-14  오후 04:10           241,007 머신러닝_01_실습1_생선분류2_DataSplit.ipynb
# 2025-10-14  오후 04:10            19,663 머신러닝_01_실습1_생선분류3_Data전처리.ipynb
# 2025-10-17  오후 05:24           267,736 머신러닝_07_실습_타이타닉생존자예측 (1).ipynb
# 2025-10-24  오전 09:15            13,053 머신러닝_07_실습2_모델성능평가연습.ipynb
# 2025-10-20  오후 03:13         1,558,648 머신러닝_08_결정트리2_실습.ipynb
# 2025-10-20  오후 12:37           122,383 머신러닝_08_결정트리3_과대적합.ipynb
# 2025-10-20  오후 02:44            46,396 머신러닝_08_결정트리4_연습문제.ipynb
# 2025-10-21  오전 11:02         1,619,982 머신러닝_08_결정트리4_연습문제2_당뇨병데이터.ipynb
# 2025-10-21  오후 12:30           162,290 머신러닝_09_앙상블학습2_Voting.ipynb
# 2025-10-22  오후 05:13            98,128 머신러닝_09_앙상블학습3_Bagging_연습문제.ipynb
# 2025-10-22  오후 02:15           281,350 머신러닝_09_앙상블학습4_Boosting_GBM.ipynb
# 2025-10-22  오후 04:18           248,227 머신러닝_09_앙상블학습5_Boosting_XGBoost.ipynb
# 2025-10-27  오전 09:51         6,538,998 머신러닝_09_앙상블학습7_Boosting_연습문제.ipynb
# 2025-10-27  오전 10:51         6,538,998 머신러닝_09_앙상블학습7_Boosting_연습문제_문창현.ipynb
# 2025-10-23  오전 11:32         1,781,508 머신러닝_09_앙상블학습7_Stacking.ipynb
# 2025-10-24  오전 09:15           597,362 머신러닝_09_앙상블학습8_HyperOpt를이용한튜닝 (1).ipynb
# 2025-10-23  오후 12:49           475,395 머신러닝_09_앙상블학습8_HyperOpt를이용한튜닝.ipynb
# 2025-10-24  오전 11:11            53,243 머신러닝_09_앙상블학습9_실습_산탄데르고객만족예측 (1).ipynb
# 2025-10-24  오후 12:43           187,368 머신러닝_11_회귀분석2_실습_비용최소화이해.ipynb
# 2025-10-27  오후 12:25           570,269 머신러닝_11_회귀분석3_실습_LinearRegression이용 (1).ipynb
# 2025-10-27  오후 03:58         2,026,153 머신러닝_11_회귀분석3_실습_Statsmodels이용.ipynb
# 2025-10-27  오전 10:34            41,825 머신러닝_11_회귀분석4_실습_LinearRegression이용.ipynb
# 2025-10-24  오전 11:11         1,621,137 머신러닝_11_회귀분석4_실습_Statsmodels이용.ipynb
# 2025-10-27  오후 05:43           223,738 머신러닝_12_다항회귀.ipynb
# 2025-10-28  오후 03:32           408,312 머신러닝_14_규제선형모델2_실습.ipynb
# 2025-10-28  오후 04:34            97,749 머신러닝_14_선형모델을위한_데이터변환.ipynb
# 2025-10-29  오전 11:41           824,330 머신러닝_15_회귀트리.ipynb
# 2025-10-29  오후 12:16           154,716 머신러닝_17_로지스틱회틱2_실습1_타이타닉생존율예측.ipynb
# 2025-10-29  오후 03:30           274,914 머신러닝_18_차원축소3_PCA_실습1.ipynb
# 2025-10-29  오후 03:31             8,930 머신러닝_18_차원축소3_PCA_실습2.ipynb
# 2025-10-29  오후 04:23         3,155,135 머신러닝_18_차원축소3_PCA_실습3.ipynb
# 2025-10-31  오전 10:22         1,322,537 머신러닝_19_군집화2_K-평균 (1).ipynb
# 2025-10-31  오전 10:34         1,800,480 머신러닝_19_군집화3_K-평균_최적화 (1).ipynb
# 2025-10-31  오전 09:47           707,682 머신러닝_19_군집화3_K-평균_최적화.ipynb
# 2025-10-31  오후 12:40         1,138,642 머신러닝_19_군집화4_Mean_Shift.ipynb
# 2025-10-31  오후 12:23         1,430,739 머신러닝_19_군집화6_DBSCAN.ipynb
# 2025-10-31  오후 05:34           716,554 머신러닝_20_군집화실습1_고객세그멘테이션.ipynb
# 2025-10-31  오후 03:00           921,720 머신러닝_20_군집화실습2_이미지분류 (1).ipynb
# 2025-10-31  오후 02:06            91,101 머신러닝_20_군집화실습2_이미지분류.ipynb
# 2025-10-14  오후 12:18    <DIR>          머신러닝수업
# 2025-10-14  오후 02:25            19,668 실습예제1_로그분석.ipynb
# 2025-10-13  오후 03:08             3,392 통계분석2_확률과확률분포2_연습문제2.ipynb
#               84개 파일          74,917,280 바이트
#               42개 디렉터리  46,086,377,472 바이트 남음

# %% [markdown]
# #### 새로운 모델에 저장된 훈련모델 가중치를 적용하여 훈련
#
# - load_weights(모델파라미터저장파일명) 메서드
#
# - save_weights()로 저장된 모델과 정확히 같은 구조를 가져야 함

# %%
new_model = build_model(keras.layers.Dropout(0.3))
new_model.load_weights(model_path + 'model.weights.h5')

# %% [markdown]
# #### 모델의 검증 정확도 확인

# %%
val_proba = new_model.predict(X_val)
val_proba[0]
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# array([6.6590841e-13, 9.7272310e-22, 1.5354522e-16, 4.1707813e-17,
#        7.8244973e-13, 1.4795671e-07, 3.4539963e-16, 2.3812361e-09,
#        9.9999988e-01, 7.3830499e-16], dtype=float32)

# %%
val_labels = np.argmax(val_proba, axis=1)
val_labels[:10]
# Out:
# array([8, 8, 7, 4, 8, 4, 1, 0, 4, 5])

# %%
y_val[:10]
# Out:
# array([8, 8, 7, 4, 8, 4, 1, 0, 4, 5], dtype=uint8)

# %% [markdown]
# #### 모델 전체 파일을 읽은 후 검증 세트의 정확도 출력
#
# - 모델 저장 파일 읽기 : load_model(파일명)
#     - load_model() 함수는 모델 파라미터와 모델 구조, 옵티마이저 상태까지 모두 복원
#     - evaluate() 메서드 사용 가능

# %%
new_model2 = keras.models.load_model(model_path+'model_whole.keras')
loss, acc = new_model2.evaluate(X_val, y_val)
loss, acc
# Out:
#  42/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9003 - loss: 0.2803
# C:\ProgramData\anaconda3\envs\tensor\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 6 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.8892 - loss: 0.3211
# (0.32110103964805603, 0.8892499804496765)

# %% [markdown]
# ## 콜백(callback)
#
# - 훈련 과정 중간에 어떤 작업을 수행할 수 있도록 도와주는 객체
# - 최상의 모델을 자동으로 저장해주거나 검증 점수가 더 이상 향상되지 않으면 종료
# - keras.callbacks 패키지에 있는 클래스들
# - 생성한 콜백객체들은 fit() 메서드의 callbacks 매개변수에 리스트로 감싸서 전달

# %% [markdown]
# ### ModelCheckpoint 콜백
# - 최상의 검증 점수를 만드는 모델 저장
#
#
# - keras.callbacks.ModelCheckpoint 클래스
#     - 생성자의 인수로 저장할 파일이름 지정
#
#
# - 형식 : keras.callbacks.ModelCheckpoint('파일이름', monitor='val_loss', save_weight_only=True)
#     - monitor='val_loss' : 검증 손실을 관찰
#     - save_weight_only :
#          - True인 경우 모델의 가중치와 절편만 저장
#          - False인 경우 전체 모델을 저장

# %%
from keras.callbacks import ModelCheckpoint

# %%
checkpt_cb = ModelCheckpoint(model_path+'fmnist_best_model.keras')
model = build_model(keras.layers.Dropout(0.3))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=20, verbose=0, validation_data=[X_val, y_val],
          callbacks=[checkpt_cb])
print('Dropout=0.3, optimizer="adam", epoch=20일때')
for item in history.history.keys():
    print(f'{item}:{history.history[item][-1]:.4f}', end=' ')
print()
draw_loss_val_plot(history)
# Out:
# Dropout=0.3, optimizer="adam", epoch=20일때
# accuracy:0.8936 loss:0.2809 val_accuracy:0.8832 val_loss:0.3247

# %% [markdown]
# ####  저장된 최상의 검증 점수를 낸 모델을 다시 읽어 예측하기

# %%
new_model = keras.models.load_model(model_path+'fmnist_best_model.keras')
loss, acc = new_model.evaluate(X_val, y_val)
loss, acc
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.8832 - loss: 0.3247
# (0.3247322142124176, 0.8832499980926514)

# %% [markdown]
# ### 조기 종료 콜백 : EearlyStopping
#
# - 과대적합이 되기 전에 훈련을 미리 중지하는 것
#     - 검증점수가 더 이상 감소하지 않고 상승하여 과대적합이 일어나면 훈련을 계속 진행하지 않고 멈추는 기법
# - 계산 비용과 시간 절약
# - 훈련 에포크 횟수를 제한하는 역할로 과대적합을 예방 -> 규제 방법 중 하나
#
#
# - 형식 : keras.callbacks.EarlyStopping(monitor='val_loss', patient, restore_best_weights=False)
#     - patience : 검증 점수가 향상되지 않더라도 지속할 수 있는 최대 에포크 횟수
#     - restore_best_weights : 최상의 모델 가중치를 복원할지 지정
#         - True 인 경우 가장 낮은 검증 손실을 낸 모델 파라미터로 되돌림
#         - 기본값은 False

# %% [markdown]
# #### EarlyStopping 콜백과 ModelCheckpoint 콜백을 사용한 모델

# %%
from keras.callbacks import EarlyStopping

# %%
checkpt_cb = ModelCheckpoint(model_path+'fmnist_best_model2.keras')
earlystop_cb = EarlyStopping(patience=3, restore_best_weights=True)
model = build_model(keras.layers.Dropout(0.3))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=20, verbose=0, validation_data=[X_val, y_val],
          callbacks=[checkpt_cb, earlystop_cb])
for item in history.history.keys():
    print(f'{item}:{history.history[item][-1]:.4f}', end=' ')
print()
draw_loss_val_plot(history)
# Out:
# accuracy:0.8901 loss:0.2940 val_accuracy:0.8835 val_loss:0.3287

# %% [markdown]
# #### 콜백 객체의 속성 확인

# %%
earlystop_cb.stopped_epoch
# Out:
# 14

# %% [markdown]
# [결과]
# - 7번째 에포크에서 가장 낮은 손실을 기록했고, 10번째 에포크에서 훈련이 중지됨
# - 조기종료를 사용하면 에포크수를 크게 지정하여 좋은 성능을 내는 모델을 찾을 수 있음
# - ModelCheckpoint콜백과 Earlystopping 콜백을 함께 사용하면 최상의 모델을 자동으로 저장해줌
# - patience값을 얼마나 지정해주느냐에따라

# %% [markdown]
# #### 조기 종료로 얻은 모델을 사용하여 검증 세트의 성능 확인

# %%
loss, acc = new_model.evaluate(X_val, y_val)
loss, acc
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8832 - loss: 0.3247
# (0.3247322142124176, 0.8832499980926514)

# %%
import pandas as pd
pd.DataFrame(history.history)
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 0   0.792271  0.588176      0.840917  0.435201
# 1   0.843458  0.433109      0.855250  0.397940
# 2   0.854312  0.400438      0.861250  0.380884
# 3   0.862083  0.380104      0.871000  0.351251
# 4   0.866896  0.364358      0.872917  0.347559
# 5   0.870229  0.352129      0.870833  0.351628
# 6   0.873937  0.341890      0.873417  0.346632
# 7   0.878042  0.331360      0.871583  0.354259
# 8   0.878771  0.325797      0.883833  0.322997
# 9   0.879979  0.319656      0.876583  0.332507
# 10  0.882333  0.313906      0.878083  0.335952
# 11  0.885542  0.308212      0.883167  0.318615
# 12  0.886542  0.303329      0.883917  0.321926
# 13  0.887625  0.298790      0.880833  0.330712
# 14  0.890125  0.293984      0.883500  0.328734

# %% [markdown]
# ---

# %% [markdown]
# ### 확인문제

# %% [markdown]
# 1. 케라스 모델의 fit() 메서드에 검증 세트를 올바르게 전달하는 코드는 무엇인가?  4
#
#     ① model.fit(... , val_input=val_input, val_target=val_target)
#     ② model.fit(... , validation_input=val_input, validation_target=val_target)
#     ③ model.fit(... , val_data=(val_input, val_target))
#     ④ model.fit(... , validation_data=(val_input, val_target))

# %% [markdown]
# 2. 이전 층의 뉴런 출력 중 70%만 사용하기 위해 드롭아웃 층을 추가하려고 한다. 옳게 설정한 것은? 2
#
#     ① Dropout(0.7)
#     ② Dropout(0.3)
#     ③ Dropout(1/0.7)
#     ④ Dropout(1/0.3)

# %% [markdown]
# 3. 케라스 모델의 가중치만 저장하는 메서드는 무엇인가?3
#
#     ① save()
#     ② load_model()
#     ③ save_weights()
#     ④ load_weights()

# %% [markdown]
# 4. 케라스의 조기 종료 콜백을 사용하려고 한다. 3번의 에포크 동안 손실이 감소되지 않으면 종료하고 최상의 모델 가중치를 복원하도록 설정한 것은 무엇인가?2
#
#     ① EarlyStopping(monitor='loss', patience=3)
#     ② EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
#     ③ EarlyStopping(monitor='accuracy', patience=3)
#     ④ EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True)

# %% [markdown]
# ### [마무리]
#
# - 드롭아웃(Dropout)
# - 콜백(Callback)
# - 조기종료
#
# ### [핵심패키지와 함수]
#
# **TensorFlow**
#
# - Dropout : 드롭아웃 층
# - save_weights() : 모든 층의 가중치와 절편을 파일에 저장
# - load_weights() : save_weights()로 저장된 파일 읽기
# - save() : 모델 구조와 모든 가중치와 절편을 파일에 저장
# - load_model() : model.save()로 저장된 모델 로드
# - ModelCheckpoint : 케라스 모델과 가중치를 일정 간격으로 저장
# - EarlyStopping :관심 지표가 더 이상 향상하지 않으면 훈련을 중지
#
# **Numpy**
# - agrmax : 배열에서 축을 따라 최대값의 인덱스 반환
