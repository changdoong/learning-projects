# %% [markdown]
# ##  신입 정규직 연봉 예측 모델
#
# ###  분석 목적
# 신입(EN) + 정규직(FT) 조건의 지원자를 대상으로, 직무, 회사 위치, 회사 규모, 재택 근무 비율 등 정보를 바탕으로
# 연봉(`salary_in_usd`)을 예측하는 회귀 모델을 구축하였습니다.
#
# ###  사용한 기법 및 절차
# - `pandas`를 활용한 데이터 전처리
# - `타겟 인코딩`을 통해 범주형 변수 처리 (예: 직무 → 해당 직무의 평균 연봉)
# - `LGBMRegressor`를 사용하여 비선형 관계 반영
# - 성능 평가지표: 결정계수(R²), 평균제곱근오차(RMSE)
#
#
# → 해당 모델은 직무별/회사 위치별 연봉 차이를 일정 수준 설명할 수 있으며,
#    실제 기업의 연봉 가이드 산정이나 구직자의 연봉 기대 범위 제시에 활용 가능합니다.
#
# ###  주요 Feature 중요도
# - `job_title` (직무): 가장 영향력이 큰 변수
# - `company_location` (회사 위치)
# - `company_size` (회사 규모)
# - `remote_ratio` (재택 비율)
#
# > ※ 고차원 범주형 변수는 상위 N개만 사용하거나 타겟 인코딩을 적용해 모델 복잡도를 낮췄습니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_df = pd.read_csv('./salaries.csv')
salary_df.head(5)
# Out:
#    work_year experience_level employment_type                job_title  \
# 0       2025               MI              FT                  Analyst
# 1       2025               MI              FT                  Analyst
# 2       2025               SE              FT        Data Quality Lead
# 3       2025               SE              FT        Data Quality Lead
# 4       2025               MI              FT  Data Quality Specialist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  142000             USD         142000                 US             0
# 1   87000             USD          87000                 US             0
# 2  218700             USD         218700                 US             0
# 3  163200             USD         163200                 US             0
# 4  121524             USD         121524                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %% [markdown]
# #### 컬럼 설명
#
# - work_year :          급여 보고 연도
# - experience_level :   경력 수준 (EN : 신입 MI : 중간 SE : 고급 EX: 관리자)
# - employment_type :    고용 계약 유형 (FT : 정규직 CT : 계약직 PT : 파트타임 FL : 프리랜서)
# - job_title :          직업 종류
# - salary :             연봉
# - salary_currency :    급여 지급 통화
# - salary_in_usd :      환율 usd로 통일
# - employee_residence : 환율 종류
# - remote_ratio :       원격 근무의 백분율
# - company_location :   회사 또는 고용주의 본사가 있는 국가
# - company_size :       회사 크기
#
# 입력 변수 : 직업 종류, 원격 근무 백분율, 회사 크기 회사 본사가 있는국가, 회사크기
# 타겟 변수 : salary_in_usd

# %%
group_SE_FT = salary_df[(salary_df['employment_type'] == 'FT') & (salary_df['experience_level'] == 'EN')]
group_SE_FT.head(5)
# Out:
#      work_year experience_level employment_type          job_title  salary  \
# 82        2025               EN              FT       Data Analyst   25000
# 83        2025               EN              FT       Data Analyst   25000
# 222       2025               EN              FT           Engineer  109500
# 223       2025               EN              FT           Engineer   60800
# 234       2025               EN              FT  Solution Engineer  126880
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 82              GBP          31645                 GB             0
# 83              GBP          31645                 GB             0
# 222             USD         109500                 CA             0
# 223             USD          60800                 CA             0
# 234             USD         126880                 US             0
#
#     company_location company_size
# 82                GB            M
# 83                GB            M
# 222               CA            M
# 223               CA            M
# 234               US            M

# %%
group_SE_FT.shape
# Out:
# (13104, 11)

# %%
sns.boxplot(x = 'company_size', y ='salary_in_usd', data = group_SE_FT)
plt.title('Salary Comparison by company size')
plt.show()

# %%
Q1 = group_SE_FT['salary_in_usd'].quantile(0.25)
Q3 = group_SE_FT['salary_in_usd'].quantile(0.75)

IQR = Q3 - Q1
upper_bound = Q3 + IQR * 1.5
lower_bound = Q1 - IQR * 1.5

outliers = group_SE_FT[(group_SE_FT['salary_in_usd'] > upper_bound) | (group_SE_FT['salary_in_usd'] < lower_bound)]
print(len(outliers))
# Out:
# 473

# %%
outliers.head()
# Out:
#       work_year experience_level employment_type                  job_title  \
# 1217       2025               EN              FT             Data Scientist
# 2260       2025               EN              FT  Machine Learning Engineer
# 2401       2025               EN              FT  Machine Learning Engineer
# 2471       2025               EN              FT          Software Engineer
# 3145       2025               EN              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1217  221000             USD         221000                 US             0
# 2260  228600             USD         228600                 US             0
# 2401  250000             USD         250000                 US             0
# 2471  379300             USD         379300                 US             0
# 3145  234000             USD         234000                 US             0
#
#      company_location company_size
# 1217               US            M
# 2260               US            M
# 2401               US            M
# 2471               US            M
# 3145               US            M

# %%
group_SE_FT.sort_values(by='salary_in_usd',ascending=False).head(15)
# Out:
#         work_year experience_level employment_type             job_title  \
# 66265        2025               EN              FT         Data Engineer
# 66266        2025               EN              FT         Data Engineer
# 133461       2024               EN              FT          Data Analyst
# 73604        2024               EN              FT    Analytics Engineer
# 60160        2025               EN              FT          Data Analyst
# 22431        2025               EN              FT   Engineering Manager
# 112650       2024               EN              FT    Research Scientist
# 22429        2025               EN              FT   Engineering Manager
# 22391        2025               EN              FT   Engineering Manager
# 112648       2024               EN              FT    Research Scientist
# 77795        2024               EN              FT  Quantitative Analyst
# 10159        2025               EN              FT          Data Analyst
# 33489        2025               EN              FT     Software Engineer
# 34588        2025               EN              FT     Research Engineer
# 10557        2025               EN              FT       Product Manager
#
#         salary salary_currency  salary_in_usd employee_residence  \
# 66265   753480             EUR         793136                 AT
# 66266   753480             EUR         793136                 AT
# 133461  774000             USD         774000                 MX
# 73604   720000             USD         720000                 US
# 60160   634000             USD         634000                 US
# 22431   560000             USD         560000                 US
# 112650  560000             USD         560000                 US
# 22429   560000             USD         560000                 US
# 22391   560000             USD         560000                 US
# 112648  532000             USD         532000                 US
# 77795   419375             EUR         465972                 CZ
# 10159   348000             GBP         440506                 GB
# 33489   440000             USD         440000                 US
# 34588   440000             USD         440000                 US
# 10557   440000             USD         440000                 US
#
#         remote_ratio company_location company_size
# 66265              0               AT            M
# 66266              0               AT            M
# 133461             0               MX            M
# 73604              0               US            M
# 60160              0               US            M
# 22431              0               US            M
# 112650             0               US            M
# 22429              0               US            M
# 22391              0               US            M
# 112648             0               US            M
# 77795              0               CZ            M
# 10159              0               GB            M
# 33489              0               US            M
# 34588              0               US            M
# 10557            100               US            M

# %%
group_SE_FT[(group_SE_FT['employee_residence'] == group_SE_FT['company_location']) == False].shape
# Out:
# (45, 11)

# %%
top30_jobs = group_SE_FT['job_title'].value_counts().index[0:30]
group_top30 = group_SE_FT[group_SE_FT['job_title'].isin(top30_jobs)].copy()

# %%
group_top30
# Out:
#         work_year experience_level employment_type                  job_title  \
# 82           2025               EN              FT               Data Analyst
# 83           2025               EN              FT               Data Analyst
# 222          2025               EN              FT                   Engineer
# 223          2025               EN              FT                   Engineer
# 400          2025               EN              FT                   Engineer
# ...           ...              ...             ...                        ...
# 146268       2021               EN              FT  Machine Learning Engineer
# 146270       2021               EN              FT             Data Scientist
# 146281       2020               EN              FT              Data Engineer
# 146303       2020               EN              FT             Data Scientist
# 146345       2020               EN              FT             Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 82        25000             GBP          31645                 GB
# 83        25000             GBP          31645                 GB
# 222      109500             USD         109500                 CA
# 223       60800             USD          60800                 CA
# 400      140000             USD         140000                 US
# ...         ...             ...            ...                ...
# 146268    81000             USD          81000                 US
# 146270    90000             USD          90000                 US
# 146281  4450000             JPY          41689                 JP
# 146303    55000             EUR          62726                 DE
# 146345   105000             USD         105000                 US
#
#         remote_ratio company_location company_size
# 82                 0               GB            M
# 83                 0               GB            M
# 222                0               CA            M
# 223                0               CA            M
# 400                0               US            M
# ...              ...              ...          ...
# 146268            50               US            S
# 146270           100               US            S
# 146281           100               JP            S
# 146303            50               DE            S
# 146345           100               US            S
#
# [12099 rows x 11 columns]

# %%
job_map = group_top30.groupby('job_title')['salary_in_usd'].mean()
group_top30['job_title_enc'] = group_top30['job_title'].map(job_map)

# %%
group_top30.head()
# Out:
#      work_year experience_level employment_type     job_title  salary  \
# 82        2025               EN              FT  Data Analyst   25000
# 83        2025               EN              FT  Data Analyst   25000
# 222       2025               EN              FT      Engineer  109500
# 223       2025               EN              FT      Engineer   60800
# 400       2025               EN              FT      Engineer  140000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 82              GBP          31645                 GB             0
# 83              GBP          31645                 GB             0
# 222             USD         109500                 CA             0
# 223             USD          60800                 CA             0
# 400             USD         140000                 US             0
#
#     company_location company_size  job_title_enc
# 82                GB            M       89379.16
# 83                GB            M       89379.16
# 222               CA            M      103377.88
# 223               CA            M      103377.88
# 400               US            M      103377.88

# %%
res_map = group_top30.groupby('company_location')['salary_in_usd'].mean()
group_top30['company_location_enc'] = group_top30['company_location'].map(res_map)

# %%
group_top30['company_size_map'] = group_top30['company_size'].map({
    'S' : 1,
    'M' : 2,
    'L' : 3
})

# %%
group_top30.head()
# Out:
#      work_year experience_level employment_type     job_title  salary  \
# 82        2025               EN              FT  Data Analyst   25000
# 83        2025               EN              FT  Data Analyst   25000
# 222       2025               EN              FT      Engineer  109500
# 223       2025               EN              FT      Engineer   60800
# 400       2025               EN              FT      Engineer  140000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 82              GBP          31645                 GB             0
# 83              GBP          31645                 GB             0
# 222             USD         109500                 CA             0
# 223             USD          60800                 CA             0
# 400             USD         140000                 US             0
#
#     company_location company_size  job_title_enc  company_location_enc  \
# 82                GB            M       89379.16              57780.01
# 83                GB            M       89379.16              57780.01
# 222               CA            M      103377.88              85756.82
# 223               CA            M      103377.88              85756.82
# 400               US            M      103377.88             107832.57
#
#      company_size_map
# 82                  2
# 83                  2
# 222                 2
# 223                 2
# 400                 2

# %%
'''import numpy as np

log_col = ['job_title_enc','company_location_enc']

for col in log_col:
    group_top30[col] = np.log1p(group_top30[col])
    '''
# Out:
# "import numpy as np\n\nlog_col = ['job_title_enc','company_location_enc']\n\nfor col in log_col:\n    group_top30[col] = np.log1p(group_top30[col])\n    "

# %%
group_top30.head()
# Out:
#      work_year experience_level employment_type     job_title  salary  \
# 82        2025               EN              FT  Data Analyst   25000
# 83        2025               EN              FT  Data Analyst   25000
# 222       2025               EN              FT      Engineer  109500
# 223       2025               EN              FT      Engineer   60800
# 400       2025               EN              FT      Engineer  140000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 82              GBP          31645                 GB             0
# 83              GBP          31645                 GB             0
# 222             USD         109500                 CA             0
# 223             USD          60800                 CA             0
# 400             USD         140000                 US             0
#
#     company_location company_size  job_title_enc  company_location_enc  \
# 82                GB            M       89379.16              57780.01
# 83                GB            M       89379.16              57780.01
# 222               CA            M      103377.88              85756.82
# 223               CA            M      103377.88              85756.82
# 400               US            M      103377.88             107832.57
#
#      company_size_map
# 82                  2
# 83                  2
# 222                 2
# 223                 2
# 400                 2

# %%
#직업 종류, 원격 근무 백분율, 회사 크기 회사 본사가 있는국가, 회사크기 
X_data = ['job_title_enc','company_location_enc','company_size_map']
X = group_top30[X_data]
y = group_top30['salary_in_usd']

# %%
y
# Out:
# 82         31645
# 83         31645
# 222       109500
# 223        60800
# 400       140000
#            ...
# 146268     81000
# 146270     90000
# 146281     41689
# 146303     62726
# 146345    105000
# Name: salary_in_usd, Length: 12099, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (9679, 3)

# %%
y_train
# Out:
# 124489    170500
# 21093      81000
# 134578    138000
# 143505    150000
# 132040     90000
#            ...
# 63601      80000
# 132766     80000
# 122770     66000
# 92194      85000
# 50344      69900
# Name: salary_in_usd, Length: 9679, dtype: int64

# %%
from lazypredict.Supervised import LazyRegressor

# %%
reg = LazyRegressor()
models, predictions = reg.fit(X_train,X_val,y_train,y_val)
print(models.head(5))
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
#                                Adjusted R-Squared  R-Squared     RMSE  \
# Model
# RandomForestRegressor                        0.26       0.26 47239.30
# HistGradientBoostingRegressor                0.26       0.26 47287.40
# LGBMRegressor                                0.26       0.26 47292.87
# XGBRegressor                                 0.26       0.26 47332.12
# BaggingRegressor                             0.25       0.26 47375.60
#
#                                Time Taken
# Model
# RandomForestRegressor                0.34
# HistGradientBoostingRegressor        0.76
# LGBMRegressor                        0.31
# XGBRegressor                         0.16
# BaggingRegressor                     0.06

# %%
import lightgbm as lgb
import optuna
from sklearn.metrics import mean_squared_error


def objective(trial):
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'reg_alpha' : trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda' : trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'random_state': 42,
        'n_jobs': -1
    }
    model = lgb.LGBMRegressor(**params,verbose=-1)
    model.fit(X_train,y_train, eval_set=[(X_val, y_val)])
    preds = model.predict(X_val)


    rmse = mean_squared_error(y_val, preds)
    return rmse


study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-08-06 10:10:55,200] A new study created in memory with name: no-name-3e465bb7-5434-4fc0-adc7-f48d81823e9b
# [I 2025-08-06 10:10:57,337] Trial 0 finished with value: 2457470014.580019 and parameters: {'num_leaves': 147, 'max_depth': 8, 'learning_rate': 0.0019747506462321385, 'n_estimators': 783, 'subsample': 0.5261762460096093, 'colsample_bytree': 0.7599041186152271, 'min_child_samples': 48, 'reg_alpha': 7.117479874490502e-07, 'reg_lambda': 9.290132711420573e-07}. Best is trial 0 with value: 2457470014.580019.
# [I 2025-08-06 10:10:59,262] Trial 1 finished with value: 2299353666.5628505 and parameters: {'num_leaves': 44, 'max_depth': 15, 'learning_rate': 0.006712564035876749, 'n_estimators': 684, 'subsample': 0.5327264272101535, 'colsample_bytree': 0.5692913055757066, 'min_child_samples': 52, 'reg_alpha': 1.583469564483603, 'reg_lambda': 0.0001826033432983264}. Best is trial 1 with value: 2299353666.5628505.
# [I 2025-08-06 10:11:01,432] Trial 2 finished with value: 2272530827.254999 and parameters: {'num_leaves': 148, 'max_depth': 8, 'learning_rate': 0.004061618579707168, 'n_estimators': 465, 'subsample': 0.7332550620386127, 'colsample_bytree': 0.933270964668854, 'min_child_samples': 39, 'reg_alpha': 5.296405589095526, 'reg_lambda': 0.006375213690543652}. Best is trial 2 with value: 2272530827.254999.
# [I 2025-08-06 10:11:01,979] Trial 3 finished with value: 2251439910.464866 and parameters: {'num_leaves': 91, 'max_depth': 11, 'learning_rate': 0.035008846339448466, 'n_estimators': 73, 'subsample': 0.7326133245682758, 'colsample_bytree': 0.8334084701774508, 'min_child_samples': 25, 'reg_alpha': 1.4335387039476674e-08, 'reg_lambda': 5.125732246437347e-06}. Best is trial 3 with value: 2251439910.464866.
# [I 2025-08-06 10:11:03,766] Trial 4 finished with value: 2251588963.391833 and parameters: {'num_leaves': 37, 'max_depth': 11, 'learning_rate': 0.007050154899190475, 'n_estimators': 367, 'subsample': 0.9201346358483525, 'colsample_bytree': 0.8776597970152313, 'min_child_samples': 13, 'reg_alpha': 0.00022786161723718903, 'reg_lambda': 0.0004260871592913497}. Best is trial 3 with value: 2251439910.464866.
# [I 2025-08-06 10:11:04,103] Trial 5 finished with value: 2270243125.3992133 and parameters: {'num_leaves': 21, 'max_depth': 8, 'learning_rate': 0.03559862930318532, 'n_estimators': 116, 'subsample': 0.9894683612406453, 'colsample_bytree': 0.9969392091471568, 'min_child_samples': 70, 'reg_alpha': 1.0072843815351664e-07, 'reg_lambda': 1.3597174569802414e-08}. Best is trial 3 with value: 2251439910.464866.
# [I 2025-08-06 10:11:05,292] Trial 6 finished with value: 2250094995.664248 and parameters: {'num_leaves': 33, 'max_depth': 5, 'learning_rate': 0.05441604747785611, 'n_estimators': 597, 'subsample': 0.9248652131343966, 'colsample_bytree': 0.5748978642356548, 'min_child_samples': 11, 'reg_alpha': 2.547341610927391e-07, 'reg_lambda': 3.6071882922423175e-07}. Best is trial 6 with value: 2250094995.664248.
. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:39,456] Trial 31 finished with value: 2231377114.7059674 and parameters: {'num_leaves': 49, 'max_depth': 10, 'learning_rate': 0.06887152350853001, 'n_estimators': 267, 'subsample': 0.9549228531495991, 'colsample_bytree': 0.8969756112736136, 'min_child_samples': 16, 'reg_alpha': 0.0009317882933778155, 'reg_lambda': 1.0854194234465241e-07}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:40,062] Trial 32 finished with value: 2234568894.06751 and parameters: {'num_leaves': 25, 'max_depth': 11, 'learning_rate': 0.08294082935249027, 'n_estimators': 173, 'subsample': 0.8730184463202807, 'colsample_bytree': 0.9597886371588762, 'min_child_samples': 11, 'reg_alpha': 0.004340807130953618, 'reg_lambda': 1.0706511968666098e-08}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:41,395] Trial 33 finished with value: 2225956292.014802 and parameters: {'num_leaves': 45, 'max_depth': 9, 'learning_rate': 0.13209516970301563, 'n_estimators': 325, 'subsample': 0.813541324584096, 'colsample_bytree': 0.8655341732269557, 'min_child_samples': 17, 'reg_alpha': 0.00014764990270409658, 'reg_lambda': 5.698821578022179e-07}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:41,884] Trial 34 finished with value: 2237216877.956726 and parameters: {'num_leaves': 31, 'max_depth': 11, 'learning_rate': 0.04455628774717996, 'n_estimators': 107, 'subsample': 0.7502860172112911, 'colsample_bytree': 0.9162419313138073, 'min_child_samples': 9, 'reg_alpha': 0.0006088781042752744, 'reg_lambda': 1.0785173976545817e-05}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:42,702] Trial 35 finished with value: 2240528514.5555673 and parameters: {'num_leaves': 52, 'max_depth': 8, 'learning_rate': 0.06814300580611518, 'n_estimators': 215, 'subsample': 0.8468321888449728, 'colsample_bytree': 0.9552730232116677, 'min_child_samples': 24, 'reg_alpha': 1.9610892499600792e-05, 'reg_lambda': 3.8371338246602295e-08}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:44,153] Trial 36 finished with value: 2242879745.055069 and parameters: {'num_leaves': 40, 'max_depth': 10, 'learning_rate': 0.022993788007637305, 'n_estimators': 265, 'subsample': 0.8949352184693952, 'colsample_bytree': 0.8475893970451677, 'min_child_samples': 28, 'reg_alpha': 0.002161823850031798, 'reg_lambda': 2.1088380190250052e-06}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:45,132] Trial 37 finished with value: 2265071222.51236 and parameters: {'num_leaves': 27, 'max_depth': 11, 'learning_rate': 0.040637627104661164, 'n_estimators': 368, 'subsample': 0.7506712585870228, 'colsample_bytree': 0.8032345741253692, 'min_child_samples': 48, 'reg_alpha': 0.3563113064860242, 'reg_lambda': 0.03182068148624734}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:45,574] Trial 38 finished with value: 2411408899.856714 and parameters: {'num_leaves': 38, 'max_depth': 7, 'learning_rate': 0.00899693971201162, 'n_estimators': 86, 'subsample': 0.7880330571744042, 'colsample_bytree': 0.9000258038466848, 'min_child_samples': 13, 'reg_alpha': 0.0001987766248809943, 'reg_lambda': 1.5647589905719398e-07}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:46,717] Trial 39 finished with value: 2223367411.5639873 and parameters: {'num_leaves': 57, 'max_depth': 12, 'learning_rate': 0.12309512903180356, 'n_estimators': 153, 'subsample': 0.9672449187958383, 'colsample_bytree': 0.8797233713896931, 'min_child_samples': 5, 'reg_alpha': 0.05468605280834959, 'reg_lambda': 2.7328326897191644e-08}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:47,579] Trial 40 finished with value: 2234324479.5629463 and parameters: {'num_leaves': 72, 'max_depth': 14, 'learning_rate': 0.20446859467559786, 'n_estimators': 146, 'subsample': 0.9447883137447406, 'colsample_bytree': 0.7364462390298011, 'min_child_samples': 8, 'reg_alpha': 6.84438626614601, 'reg_lambda': 2.6312967470590464e-08}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:49,589] Trial 41 finished with value: 2221620836.9315953 and parameters: {'num_leaves': 57, 'max_depth': 12, 'learning_rate': 0.12220414248412934, 'n_estimators': 309, 'subsample': 0.9127171418223531, 'colsample_bytree': 0.8794707954772096, 'min_child_samples': 13, 'reg_alpha': 0.04697381894328023, 'reg_lambda': 4.1231209949418163e-07}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:52,656] Trial 42 finished with value: 2233037129.0896416 and parameters: {'num_leaves': 58, 'max_depth': 12, 'learning_rate': 0.11993726185794963, 'n_estimators': 428, 'subsample': 0.9854040517268842, 'colsample_bytree': 0.8543283509200535, 'min_child_samples': 5, 'reg_alpha': 0.05775625035089301, 'reg_lambda': 4.49147622744695e-07}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:53,991] Trial 43 finished with value: 2239801510.6433268 and parameters: {'num_leaves': 65, 'max_depth': 14, 'learning_rate': 0.18077912843819702, 'n_estimators': 322, 'subsample': 0.9107663411321631, 'colsample_bytree': 0.8206207821161895, 'min_child_samples': 22, 'reg_alpha': 1.9547998538590874, 'reg_lambda': 1.986238631682514e-08}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:11:55,441] Trial 44 finished with value: 2223034906.7724924 and parameters: {'num_leaves': 88, 'max_depth': 12, 'learning_rate': 0.2392706790947212, 'n_estimators': 185, 'subsample': 0.9617946597712594, 'colsample_bytree': 0.8958764757775021, 'min_child_samples': 11, 'reg_alpha': 0.12858239984920444, 'reg_lambda': 2.3526387528261048e-07}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:12:00,749] Trial 45 finished with value: 2237024929.8758016 and parameters: {'num_leaves': 83, 'max_depth': 13, 'learning_rate': 0.2873002000484085, 'n_estimators': 661, 'subsample': 0.921293537387087, 'colsample_bytree': 0.9480519489541235, 'min_child_samples': 17, 'reg_alpha': 0.007641692046840541, 'reg_lambda': 2.1256445789670517e-06}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:12:01,912] Trial 46 finished with value: 2234580666.578737 and parameters: {'num_leaves': 91, 'max_depth': 11, 'learning_rate': 0.21795109613351873, 'n_estimators': 238, 'subsample': 0.8497982244073601, 'colsample_bytree': 0.7734491478964909, 'min_child_samples': 11, 'reg_alpha': 0.5524150940610533, 'reg_lambda': 2.4522873604381435e-05}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:12:03,326] Trial 47 finished with value: 2237751343.1745915 and parameters: {'num_leaves': 114, 'max_depth': 12, 'learning_rate': 0.16402645200108665, 'n_estimators': 357, 'subsample': 0.9689708525773657, 'colsample_bytree': 0.9024400537982822, 'min_child_samples': 67, 'reg_alpha': 0.020423788401485045, 'reg_lambda': 6.437331954644814e-07}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:12:07,112] Trial 48 finished with value: 2233081061.6952915 and parameters: {'num_leaves': 107, 'max_depth': 13, 'learning_rate': 0.23624126211896065, 'n_estimators': 510, 'subsample': 0.8307567937709693, 'colsample_bytree': 0.9722189648216901, 'min_child_samples': 19, 'reg_alpha': 1.1950767116752886e-08, 'reg_lambda': 0.00010665924449878912}. Best is trial 17 with value: 2221163634.1199207.
# [I 2025-08-06 10:12:10,245] Trial 49 finished with value: 2306782829.8915906 and parameters: {'num_leaves': 95, 'max_depth': 14, 'learning_rate': 0.004897688479083084, 'n_estimators': 800, 'subsample': 0.9997018601234697, 'colsample_bytree': 0.8049494290057526, 'min_child_samples': 29, 'reg_alpha': 0.005919013310867749, 'reg_lambda': 2.056282952079682e-07}. Best is trial 17 with value: 2221163634.1199207.

# %%
print(f'rmse : {study.best_value:.4f}')
# Out:
# rmse : 2221163634.1199

# %%
best_params = study.best_params
best_params.update({'objective' : 'regression', 'metric' : 'rmse'})

final_model = lgb.LGBMRegressor(**best_params)
final_model.fit(X,y)
# Out:
# LGBMRegressor(colsample_bytree=0.8358822583962509,
#               learning_rate=0.019418604752537226, max_depth=12, metric='rmse',
#               min_child_samples=5, n_estimators=149, num_leaves=112,
#               objective='regression', reg_alpha=0.0007462457561056988,
#               reg_lambda=5.7283519375518016e-08, subsample=0.8403085734030119)

# %%
preds = final_model.predict(X)

# %%
result_df = group_top30.copy()
result_df['pred_salary'] = preds

# %%
result_df.tail()
# Out:
#         work_year experience_level employment_type                  job_title  \
# 146268       2021               EN              FT  Machine Learning Engineer
# 146270       2021               EN              FT             Data Scientist
# 146281       2020               EN              FT              Data Engineer
# 146303       2020               EN              FT             Data Scientist
# 146345       2020               EN              FT             Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 146268    81000             USD          81000                 US
# 146270    90000             USD          90000                 US
# 146281  4450000             JPY          41689                 JP
# 146303    55000             EUR          62726                 DE
# 146345   105000             USD         105000                 US
#
#         remote_ratio company_location company_size  job_title_enc  \
# 146268            50               US            S      150271.48
# 146270           100               US            S      102891.56
# 146281           100               JP            S       93873.64
# 146303            50               DE            S      102891.56
# 146345           100               US            S      102891.56
#
#         company_location_enc  company_size_map  pred_salary
# 146268             107832.57                 1    102819.17
# 146270             107832.57                 1    101671.67
# 146281              38211.25                 1     60332.60
# 146303              72569.31                 1     70226.10
# 146345             107832.57                 1    101671.67

# %%
plt.figure(figsize=(10,6))
plt.scatter(result_df['salary_in_usd'], result_df['pred_salary'],alpha=0.5)
plt.plot([result_df['salary_in_usd'].min(), result_df['salary_in_usd'].max()],
        [result_df['salary_in_usd'].min(), result_df['salary_in_usd'].max()],
        'r--')
plt.grid()
plt.title('Comparison of Prediction Results')
plt.xlabel('actual salary')
plt.ylabel('predict salary')
plt.show()

# %% [markdown]
# #### 결과:
# - 예측 성능 매우 낮음
# - 실제값 분포가 심하게 치우쳐 있었고, 예측값은 200,000을 넘게 예측한 값이 없음
#
# #### 분석:
# - 로그 변환 및 하이퍼파라미터 조정 시도도 해봤지만 큰 개선 없었음
# - 일부 외생적 요인 (예: 위치, 산업 등) 데이터 미포함으로 영향
# - 예측은 어려웠지만, 예측 실패를 통해 데이터 특성과 한계 파악
# - 컬럼 수 부족이 절대적 이유
#
# #### 배운 점:
# - 데이터 분포의 왜곡이 모델 성능에 미치는 영향
# - 평가 지표 선택의 중요성
# - 예측이 어려운 문제를 설명하는 것도 데이터 과학자의 역할
# - 데이터 질의 중요성
