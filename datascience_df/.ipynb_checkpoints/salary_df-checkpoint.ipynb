# %% [markdown]
# # 문제 정의 : 직무 / 경력 / 고용 형태 / 회사 규모에 따른 연봉 비교
# #### 사용 분석 방법 : 드릴다운(Drill-down)

# %%
import pandas as pd

salary_df = pd.read_csv('salaries.csv')
salary_df
# Out:
#         work_year experience_level employment_type                 job_title  \
# 0            2025               MI              FT                   Analyst
# 1            2025               MI              FT                   Analyst
# 2            2025               SE              FT         Data Quality Lead
# 3            2025               SE              FT         Data Quality Lead
# 4            2025               MI              FT   Data Quality Specialist
# ...           ...              ...             ...                       ...
# 146343       2020               SE              FT            Data Scientist
# 146344       2021               MI              FT  Principal Data Scientist
# 146345       2020               EN              FT            Data Scientist
# 146346       2020               EN              CT     Business Data Analyst
# 146347       2021               SE              FT            Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0        142000             USD         142000                 US
# 1         87000             USD          87000                 US
# 2        218700             USD         218700                 US
# 3        163200             USD         163200                 US
# 4        121524             USD         121524                 US
# ...         ...             ...            ...                ...
# 146343   412000             USD         412000                 US
# 146344   151000             USD         151000                 US
# 146345   105000             USD         105000                 US
# 146346   100000             USD         100000                 US
# 146347  7000000             INR          94665                 IN
#
#         remote_ratio company_location company_size
# 0                  0               US            M
# 1                  0               US            M
# 2                  0               US            M
# 3                  0               US            M
# 4                  0               US            M
# ...              ...              ...          ...
# 146343           100               US            L
# 146344           100               US            L
# 146345           100               US            S
# 146346           100               US            L
# 146347            50               IN            L
#
# [146348 rows x 11 columns]

# %% [markdown]
# #### 컬럼 설명
#
# - work_year :          급여 보고 연도
# - experience_level :   경력 수준 (EN : 신입 MI : 중간 SE : 고급 EX: 관리자)
# - employment_type :    고용 계약 유형 (FT : 정규직 CT : 계약직 PT : 파트타임 FL : 프리랜서)
# - job_title :          직업 종류
# - salary :             연봉
# - salary_currency :    급여 지급 통화
# - salary_in_usd :      환율 usd로 통일
# - employee_residence : 환율 종류
# - remote_ratio :       원격 근무의 백분율
# - company_location :   회사 또는 고용주의 본사가 있는 국가
# - company_size :       회사 크기

# %%
salary_df.shape
# Out:
# (146348, 11)

# %%
salary_df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
salary_df['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EX', 'EN'], dtype=object)

# %%
group_SE = salary_df[salary_df['experience_level'] == 'SE']
group_MI = salary_df[salary_df['experience_level'] == 'MI']
group_EX = salary_df[salary_df['experience_level'] == 'EX']
group_EN = salary_df[salary_df['experience_level'] == 'EN']

# %%
print(group_SE.shape)
print(group_MI.shape)
print(group_EX.shape)
print(group_EN.shape)
# Out:
# (84659, 11)
# (44410, 11)
# (3813, 11)
# (13466, 11)

# %%
group_SE.head()
# Out:
#     work_year experience_level employment_type                  job_title  \
# 2        2025               SE              FT          Data Quality Lead
# 3        2025               SE              FT          Data Quality Lead
# 10       2025               SE              FT  Machine Learning Engineer
# 11       2025               SE              FT  Machine Learning Engineer
# 14       2025               SE              FT  Machine Learning Engineer
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 2   218700             USD         218700                 US             0
# 3   163200             USD         163200                 US             0
# 10  166000             USD         166000                 US             0
# 11  114000             USD         114000                 US             0
# 14  256500             USD         256500                 US           100
#
#    company_location company_size
# 2                US            M
# 3                US            M
# 10               US            M
# 11               US            M
# 14               US            M

# %% [markdown]
# ## 단순 비교

# %%
# 신입 연봉 비교
pd.DataFrame(group_EN.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False)).tail(20)
# Out:
#                                     salary_in_usd
# job_title
# Research Specialist                  45250.000000
# Compliance Data Analyst              45000.000000
# Staff Data Analyst                   44753.000000
# Robotics Engineer                    42761.800000
# Data Management Consultant           41000.000000
# Applied Machine Learning Scientist   40766.666667
# Finance Data Analyst                 40000.000000
# Technical Specialist                 40000.000000
# Data Analysis                        38131.500000
# Data Operations                      38000.000000
# Machine Learning Specialist          37549.000000
# AI Content Writer                    30000.000000
# AI Research Engineer                 29216.250000
# Stage                                28759.833333
# Data Quality Engineer                23753.000000
# Web Developer                        22584.000000
# Data Platform Engineer               21052.000000
# Data Analytics Engineer              20000.000000
# Alternance                           19825.000000
# Data Analyst Lead                    18000.000000

# %%
#고급 인력 연봉 비교
pd.DataFrame(group_SE.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False)).head(7)
# Out:
#                                salary_in_usd
# job_title
# Research Team Lead             450000.000000
# Analytics Engineering Manager  399880.000000
# Data Science Tech Lead         375000.000000
# Applied AI ML Lead             292500.000000
# IT Enterprise Data Architect   284090.000000
# Director of Machine Learning   281616.666667
# Deep Learning Engineer         272374.000000

# %%
# 관리자 연봉 비교
pd.DataFrame(group_EX.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False)).head(7)
# Out:
#                           salary_in_usd
# job_title
# Principal Data Scientist       416000.0
# Research Engineer              290000.0
# Principal Engineer             280000.0
# Technical Lead                 280000.0
# AI Developer                   276000.0
# Head of Applied AI             273875.0
# Director of Data               270000.0

# %% [markdown]
# #### 해석
#
# 1. 신입 테이블에 관리자, 책임자가 있는 것으로 보아 경력이 많지만 신입으로 분류된 데이터가 있을 가능성 多
# 2. 신입 테이블에 책임자, 관리자를 제외한 순위를 보면 연구원, ai 관련 직업이 많음 (석,박사 학위가 많기 때문으로 해석됨)
# 3. SE(고급) 테이블의 상위 연봉이 EX(관리자)의 상위 연봉보다 높은데 관리자의 데이터가 부족해 평균 왜곡 가능성이 있음
#    혹은 실제로 관리자가 코딩/모델링에 참여하지 않기 때문에 기술력측면에서 고급 엔지니어보다 연봉이 낮게 책정될 가능성이 있음

# %%
# FT : 정규직 CT : 계약직 PT : 파트타임 FL : 프리랜서
group_SE_FT = group_SE[group_SE['employment_type'] == 'FT']
group_SE_CT = group_SE[group_SE['employment_type'] == 'CT']
group_SE_PT = group_SE[group_SE['employment_type'] == 'PT']
group_SE_FL = group_SE[group_SE['employment_type'] == 'FL']

# %%
print(group_SE_FT.shape)
print(group_SE_CT.shape)
print(group_SE_PT.shape)
print(group_SE_FL.shape)
# Out:
# (84452, 11)
# (145, 11)
# (56, 11)
# (6, 11)

# %%
group_SE_FT['employee_residence'].value_counts()
# Out:
# employee_residence
# US    77384
# CA     3260
# GB     1620
# DE      197
# AU      194
#       ...
# CF        2
# RU        1
# OM        1
# SA        1
# MD        1
# Name: count, Length: 66, dtype: int64

# %%
group_SE_CT['employee_residence'].value_counts()
# Out:
# employee_residence
# US    114
# IN      8
# CA      5
# FR      5
# BR      2
# LT      2
# AU      2
# MX      2
# GB      2
# EG      2
# PL      1
# Name: count, dtype: int64

# %%
group_SE_PT['employee_residence'].value_counts()
# Out:
# employee_residence
# US    46
# CA     6
# GB     2
# DE     1
# AE     1
# Name: count, dtype: int64

# %%
group_SE_FL['employee_residence'].value_counts()
# Out:
# employee_residence
# NG    2
# CZ    1
# IN    1
# UA    1
# RU    1
# Name: count, dtype: int64

# %% [markdown]
# #### 해석
# 1. 미국의 경우 At-will 고용법이 있어 해고가 자유롭기 때문에 정규직의 비율이 많음 (그 외에는 데이터 수가 너무 적어 해석 x)
# 2. 데이터는 적지만 상위권에 해당하는 나라를 보면 정규직 자체가 보호받는 국가들이 많음
# 3. 데이터 수집을 미국 기준으로 한 것 같음

# %%
# 고급 중에서 계약직의 직업별 연봉 평균
pd.DataFrame(group_SE_CT.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False).tail(5))
# Out:
#                                   salary_in_usd
# job_title
# Data Developer                    110860.000000
# Staff Data Scientist              105000.000000
# Analyst                            85583.333333
# Machine Learning Engineer          38000.000000
# Artificial Intelligence Engineer   30000.000000

# %%
pd.DataFrame(group_SE_CT['job_title'] == 'Finance Data Analyst').value_counts()
# Out:
# job_title
# False        144
# True           1
# Name: count, dtype: int64

# %%
pd.DataFrame(group_SE_CT['job_title'] == 'Machine Learning Engineer')
# Out:
#         job_title
# 276         False
# 277         False
# 2070        False
# 2071        False
# 2465        False
# ...           ...
# 134220      False
# 141076      False
# 142419      False
# 145306      False
# 146233      False
#
# [145 rows x 1 columns]

# %%
# 고급 중에서 정규직의 직업별 연봉 평균
pd.DataFrame(group_SE_FT.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False).tail(5))
# Out:
#                                    salary_in_usd
# job_title
# Computer Vision Software Engineer        53984.0
# Consultant Data Engineer                 50000.0
# Principal Data Architect                 38154.0
# AI Software Development Engineer         25210.0
# AI Engineering Lead                      23649.0

# %%
# 고급 중에서 파트타임 직업의 직업별 연봉 평균
pd.DataFrame(group_SE_PT.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False).tail(5))
# Out:
#                      salary_in_usd
# job_title
# DevOps Engineer            73333.0
# Solutions Architect        68530.0
# Developer                  57142.5
# Data Specialist            49500.0
# CRM Data Analyst           40000.0

# %%
# 신입 중에서 프리랜서의 직업별 연봉 평균
pd.DataFrame(group_SE_FL.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False).tail(5))
# Out:
#                              salary_in_usd
# job_title
# Computer Vision Engineer           60000.0
# Machine Learning Developer         60000.0
# Machine Learning Researcher        50000.0
# Software Data Engineer             50000.0
# Manager Data Management            36014.0

# %% [markdown]
# #### 해석
# 1. 신입의 경우 정규직으로 근무하는 것이 대부분의 직업에서 가장

# %%
group_SE_PT.head(5)
# Out:
#       work_year experience_level employment_type        job_title  salary  \
# 1044       2025               SE              PT  Data Specialist   52000
# 1045       2025               SE              PT  Data Specialist   47000
# 1074       2025               SE              PT          Analyst  138000
# 1075       2025               SE              PT          Analyst   92000
# 7518       2024               SE              PT  DevOps Engineer   66000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1044             USD          52000                 US             0
# 1045             USD          47000                 US             0
# 1074             USD         138000                 US             0
# 1075             USD          92000                 US             0
# 7518             EUR          73333                 DE           100
#
#      company_location company_size
# 1044               US            M
# 1045               US            M
# 1074               US            M
# 1075               US            M
# 7518               DE            M

# %%
group_SE_FL.head(5)
# Out:
#         work_year experience_level employment_type  \
# 104563       2024               SE              FL
# 130699       2024               SE              FL
# 142324       2021               SE              FL
# 142966       2023               SE              FL
# 143497       2023               SE              FL
#
#                           job_title   salary salary_currency  salary_in_usd  \
# 104563             Backend Engineer  1380000             CZK          61333
# 130699      Manager Data Management  3000000             INR          36014
# 142324   Machine Learning Developer    60000             USD          60000
# 142966  Machine Learning Researcher    50000             USD          50000
# 143497       Software Data Engineer    50000             USD          50000
#
#        employee_residence  remote_ratio company_location company_size
# 104563                 CZ             0               CZ            M
# 130699                 IN           100               IN            S
# 142324                 NG           100               NG            M
# 142966                 UA            50               UA            S
# 143497                 NG            50               AU            M
