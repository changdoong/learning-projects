# %% [markdown]
# # 실습예제2 : 자전거 대여 데이터 분석

# %% [markdown]
# Kaggle :  https://www.kaggle.com/c/bike-sharing-demand

# %% [markdown]
# #### features
#
# - datetime - hourly date + timestamp
# - season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
# - holiday - whether the day is considered a holiday
# - workingday - whether the day is neither a weekend nor holiday
# - weather
#     - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#     - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp - temperature in Celsius
# - atemp - "feels like" temperature in Celsius
# - humidity - relative humidity
# - windspeed - wind speed
# - casual - number of non-registered user rentals initiated
# - registered - number of registered user rentals initiated
# - count - number of total rentals

# %% [markdown]
# ### 모듈 임포트

# %% [markdown]
# ## 1. 데이터 수집 및 데이터 파악

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# Out:
#           datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ### 범주형 변수들의 빈도표

# %%
# Out:
# 컬럼 season 빈도표
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: season, dtype: int64
#
# 컬럼 holiday 빈도표
# 0    10575
# 1      311
# Name: holiday, dtype: int64
#
# 컬럼 workingday 빈도표
# 1    7412
# 0    3474
# Name: workingday, dtype: int64
#
# 컬럼 weather 빈도표
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64

# %% [markdown]
# ## 2. 데이터 변경 및 조작

# %% [markdown]
# ### 변수 타입 변경

# %% [markdown]
# - int형을 category로 변경

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  category
#  2   holiday     10886 non-null  category
#  3   workingday  10886 non-null  category
#  4   weather     10886 non-null  category
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: category(4), float64(3), int64(4), object(1)
# memory usage: 723.7+ KB

# %%
# 범주형 변수로 변경 후 빈도표
# Out:
# 컬럼 season 빈도표
# spring    2686
# summer    2733
# fall      2733
# winter    2734
# Name: season, dtype: int64
#
# 컬럼 holiday 빈도표
# 0    10575
# 1      311
# Name: holiday, dtype: int64
#
# 컬럼 workingday 빈도표
# 0    3474
# 1    7412
# Name: workingday, dtype: int64
#
# 컬럼 weather 빈도표
# Clear             7192
# Mist+             2834
# LightRain/Snow     859
# HeavyRain            1
# Name: weather, dtype: int64

# %% [markdown]
# - 휴일여부와 근무여부에 대한 교차표

# %%
# Out:
# workingday     0     1
# holiday
# 0           3163  7412
# 1            311     0

# %% [markdown]
# ### 날짜 컬럼에서 일자와 시간대, 요일 추출

# %% [markdown]
# - date를 날짜시간형으로 변경

# %%
# date  날짜시간형으로 변경
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  category
#  2   holiday     10886 non-null  category
#  3   workingday  10886 non-null  category
#  4   weather     10886 non-null  category
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: category(4), datetime64[ns](1), float64(3), int64(4)
# memory usage: 723.7 KB

# %% [markdown]
# - date에서 월(month),일(day),시간(hour),요일(day_of_week) 추출하여 변수로 생성

# %%
# date에서 월(month),일(day),시간(hour),요일(day_of_week) 추출
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     10886 non-null  datetime64[ns]
#  1   season       10886 non-null  category
#  2   holiday      10886 non-null  category
#  3   workingday   10886 non-null  category
#  4   weather      10886 non-null  category
#  5   temp         10886 non-null  float64
#  6   atemp        10886 non-null  float64
#  7   humidity     10886 non-null  int64
#  8   windspeed    10886 non-null  float64
#  9   casual       10886 non-null  int64
#  10  registered   10886 non-null  int64
#  11  count        10886 non-null  int64
#  12  month        10886 non-null  int64
#  13  day          10886 non-null  int64
#  14  hour         10886 non-null  int64
#  15  day_of_week  10886 non-null  int64
# dtypes: category(4), datetime64[ns](1), float64(3), int64(8)
# memory usage: 1.0 MB

# %%
# Out:
#              datetime  season holiday workingday weather  temp   atemp  \
# 0 2011-01-01 00:00:00  spring       0          0   Clear  9.84  14.395
# 1 2011-01-01 01:00:00  spring       0          0   Clear  9.02  13.635
# 2 2011-01-01 02:00:00  spring       0          0   Clear  9.02  13.635
# 3 2011-01-01 03:00:00  spring       0          0   Clear  9.84  14.395
# 4 2011-01-01 04:00:00  spring       0          0   Clear  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  month  day  hour  \
# 0        81        0.0       3          13     16      1    1     0
# 1        80        0.0       8          32     40      1    1     1
# 2        80        0.0       5          27     32      1    1     2
# 3        75        0.0       3          10     13      1    1     3
# 4        75        0.0       0           1      1      1    1     4
#
#    day_of_week
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5

# %% [markdown]
# #### 생성한 month, day, hour,day_of_week에 대한 빈도표

# %%
# Out:
# 1     575
# 2     573
# 3     573
# 4     574
# 5     575
# 6     572
# 7     574
# 8     574
# 9     575
# 10    572
# 11    568
# 12    573
# 13    574
# 14    574
# 15    574
# 16    574
# 17    575
# 18    563
# 19    574
# Name: day, dtype: int64

# %%
# Out:
# 1     884
# 2     901
# 3     901
# 4     909
# 5     912
# 6     912
# 7     912
# 8     912
# 9     909
# 10    911
# 11    911
# 12    912
# Name: month, dtype: int64

# %%
# Out:
# 0    1551
# 1    1539
# 2    1551
# 3    1553
# 4    1529
# 5    1584
# 6    1579
# Name: day_of_week, dtype: int64

# %%
# Out:
# 0     455
# 1     454
# 2     448
# 3     433
# 4     442
# 5     452
# 6     455
# 7     455
# 8     455
# 9     455
# 10    455
# 11    455
# 12    456
# 13    456
# 14    456
# 15    456
# 16    456
# 17    456
# 18    456
# 19    456
# 20    456
# 21    456
# 22    456
# 23    456
# Name: hour, dtype: int64

# %% [markdown]
# - month, day, hour, day_of_week를 범주형 변수로 변경

# %%
# month, day, hour, day_of_week를 범주형 변수로 변경
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     10886 non-null  datetime64[ns]
#  1   season       10886 non-null  category
#  2   holiday      10886 non-null  category
#  3   workingday   10886 non-null  category
#  4   weather      10886 non-null  category
#  5   temp         10886 non-null  float64
#  6   atemp        10886 non-null  float64
#  7   humidity     10886 non-null  int64
#  8   windspeed    10886 non-null  float64
#  9   casual       10886 non-null  int64
#  10  registered   10886 non-null  int64
#  11  count        10886 non-null  int64
#  12  month        10886 non-null  category
#  13  day          10886 non-null  category
#  14  hour         10886 non-null  int64
#  15  day_of_week  10886 non-null  category
#  16  hours        10886 non-null  category
# dtypes: category(8), datetime64[ns](1), float64(3), int64(5)
# memory usage: 853.0 KB

# %% [markdown]
# ## 3. 데이터 탐색
#
# - 빈도 및 분포 분석

# %% [markdown]
# #### 수치형 변수들의 기술통계량

# %%
# Out:
#               temp         atemp      humidity     windspeed        casual  \
# count  10886.00000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      20.23086     23.655084     61.886460     12.799395     36.021955
# std        7.79159      8.474601     19.245033      8.164537     49.960477
# min        0.82000      0.760000      0.000000      0.000000      0.000000
# 25%       13.94000     16.665000     47.000000      7.001500      4.000000
# 50%       20.50000     24.240000     62.000000     12.998000     17.000000
# 75%       26.24000     31.060000     77.000000     16.997900     49.000000
# max       41.00000     45.455000    100.000000     56.996900    367.000000
#
#          registered         count          hour
# count  10886.000000  10886.000000  10886.000000
# mean     155.552177    191.574132     11.541613
# std      151.039033    181.144454      6.915838
# min        0.000000      1.000000      0.000000
# 25%       36.000000     42.000000      6.000000
# 50%      118.000000    145.000000     12.000000
# 75%      222.000000    284.000000     18.000000
# max      886.000000    977.000000     23.000000

# %% [markdown]
# #### 계절별(season) 수치형 변수들의 기술통계량

# %%
# 계절별(season) 기술통계량
# Out:
# season           spring       summer         fall       winter
# temp count  2686.000000  2733.000000  2733.000000  2734.000000
#      mean     12.530491    22.823483    28.789111    16.649239
#      std       5.186492     5.159616     3.898157     4.742176
#      min       0.820000     9.840000    15.580000     5.740000
#      25%       9.020000    18.860000    26.240000    13.120000
# ...                 ...          ...          ...          ...
# hour min       0.000000     0.000000     0.000000     0.000000
#      25%       6.000000     6.000000     6.000000     6.000000
#      50%      12.000000    12.000000    12.000000    12.000000
#      75%      18.000000    18.000000    18.000000    17.750000
#      max      23.000000    23.000000    23.000000    23.000000
#
# [64 rows x 4 columns]

# %% [markdown]
# #### 날씨별(weather) 수치형 변수들의 기술통계량

# %%
# 날씨별(weather) 기술통계량
# Out:
# weather           Clear        Mist+  LightRain/Snow  HeavyRain
# temp count  7192.000000  2834.000000      859.000000        1.0
#      mean     20.557122    19.614608       19.546356        8.2
#      std       8.144427     7.172559        6.449593        NaN
#      min       0.820000     3.280000        3.280000        8.2
#      25%      13.940000    13.940000       14.760000        8.2
# ...                 ...          ...             ...        ...
# hour min       0.000000     0.000000        0.000000       18.0
#      25%       6.000000     5.000000        6.000000       18.0
#      50%      12.000000    11.000000       12.000000       18.0
#      75%      18.000000    16.000000       18.000000       18.0
#      max      23.000000    23.000000       23.000000       18.0
#
# [64 rows x 4 columns]

# %% [markdown]
# #### 월별 자전거대여와 관련된 변수들에 대한 기술통계

# %%
# 월별 자전거 대여 빈도 기술통계량
# Out:
#           casual             registered                   count
#             mean        std        mean         std        mean         std
# month
# 1       8.203620  15.577205   82.162896   87.279160   90.366516   95.302518
# 2      10.318535  19.071665   99.684795  102.154526  110.003330  109.802322
# 3      27.809101  45.559206  120.360710  127.340950  148.169811  155.352814
# 4      43.798680  61.034187  140.361936  144.634203  184.160616  182.417619
# 5      45.268640  53.513267  174.190789  156.240227  219.459430  189.320173
# 6      53.260965  57.778200  188.770833  163.200567  242.031798  199.628690
# 7      55.862939  52.763747  179.462719  154.756169  235.325658  184.857337
# 8      50.296053  49.541189  183.822368  165.753614  234.118421  197.198461
# 9      50.496150  60.881712  183.309131  172.343532  233.805281  208.915910
# 10     41.807903  54.669731  185.891328  173.823639  227.699232  204.079411
# 11     27.829857  40.639620  165.847420  143.563616  193.677278  165.420965
# 12     16.118421  21.841390  159.495614  144.105302  175.614035  155.926050

# %% [markdown]
# #### 월별 자전거대여수(count)에 대한 평균, 표준편차, 최소값, 최대값

# %%
# Out:
#             count
#              mean         std min  max
# month
# 1       90.366516   95.302518   1  512
# 2      110.003330  109.802322   1  539
# 3      148.169811  155.352814   1  801
# 4      184.160616  182.417619   1  822
# 5      219.459430  189.320173   1  873
# 6      242.031798  199.628690   1  869
# 7      235.325658  184.857337   1  872
# 8      234.118421  197.198461   1  897
# 9      233.805281  208.915910   1  977
# 10     227.699232  204.079411   1  948
# 11     193.677278  165.420965   1  724
# 12     175.614035  155.926050   1  759

# %% [markdown]
# #### 시간대별 자전거 대여수에 대한 기술통계량

# %%
# Out:
#            count
#             mean         std min  max
# hour
# 0      55.138462   43.620012   2  283
# 1      33.859031   34.112105   1  168
# 2      22.899554   26.110267   1  119
# 3      11.757506   12.666442   1   66
# 4       6.407240    4.217633   1   28
# 5      19.767699   12.784293   1   57
# 6      76.259341   54.745333   1  213
# 7     213.116484  159.207044   1  596
# 8     362.769231  231.723065   8  839
# 9     221.780220   92.099209  14  414
# 10    175.092308  101.807629  17  539
# 11    210.674725  127.444294  10  647
# 12    256.508772  143.881880   3  757
# 13    257.787281  149.167185  11  729
# 14    243.442982  147.563199  12  730
# 15    254.298246  144.235670   7  724
# 16    316.372807  145.664786  11  783
# 17    468.765351  223.775485  15  970
# 18    430.859649  219.908138  23  977
# 19    315.278509  156.641732  11  743
# 20    228.517544  116.411565  11  551
# 21    173.370614   87.629319   6  584
# 22    133.576754   69.844495   9  502
# 23     89.508772   51.638004   4  256

# %% [markdown]
# #### 시간대별 자전거대여수(count)에 대한 박스플롯

# %%
# 시간대별 대여수에 대한 박스플롯

# %% [markdown]
# #### 월별 자전거대여수(count)에 대한 박스플롯

# %%
# 월별 대여수에 대한 박스플롯

# %% [markdown]
# #### 요일별 자전거 대여수(count)에 대한 박스플롯

# %%
# 요일별 자전거 대여수

# %% [markdown]
# #### 계절과 시간대별 자전거대여수합계에 대한 피봇테이블 생성

# %%
# 계절과 시간대별 자전거대여수합계에 대한 피봇테이블
# Out:
# hours     0~2   3~5    6~8   9~11   12~14   15~17   18~20  21~23
# season
# spring   6730  2215  47517  42851   53175   71955   63711  24344
# summer  13406  4384  80420  76620   96669  135077  129817  51889
# fall    17276  5638  87133  82778  102348  140410  143687  61392
# winter  13307  4621  81656  74185   93337  126541  107228  43159

# %% [markdown]
# #### 계절과 시간대별 평균자전거대여수에 대한 피봇테이블 생성

# %%
# 계절과 시간대별 평균자전거대여수에 대한 피봇테이블
# Out:
# hours         0~2        3~5         6~8        9~11       12~14       15~17  \
# season
# spring  20.210210   7.214984  140.168142  126.404130  155.482456  210.394737
# summer  39.198830  12.932153  235.146199  224.035088  282.657895  394.961988
# fall    50.811765  16.533724  254.774854  242.040936  299.263158  410.555556
# winter  38.909357  13.591176  238.760234  216.915205  272.915205  370.002924
#
# hours        18~20       21~23
# season
# spring  186.289474   71.181287
# summer  379.581871  151.722222
# fall    420.137427  179.508772
# winter  313.532164  126.195906

# %% [markdown]
# #### 계절과 시간대별 평균자전거대여수에 대한 히트맵

# %%
# 계절과 시간대별 평균자전거대여수에 대한 heatmap()

# %% [markdown]
# #### 날씨와 시간대별 평균자전거대여수에 대한 피봇테이블 생성

# %%
# 날씨와 시간대별 평균자전거대여수에 대한 피봇테이블
# Out:
# hours                 0~2        3~5         6~8        9~11       12~14  \
# weather
# Clear           39.493333  12.808486  217.248826  217.892216  276.096921
# Mist+           36.866295  13.676966  245.713555  193.090909  227.832918
# LightRain/Snow  19.795918   8.282828  127.508197  105.933333  133.677778
# HeavyRain             NaN        NaN         NaN         NaN         NaN
#
# hours                15~17       18~20       21~23
# weather
# Clear           373.144515  344.552905  142.253178
# Mist+           315.044983  310.400709  120.506329
# LightRain/Snow  222.854962  203.280992   77.935185
# HeavyRain              NaN  164.000000         NaN

# %% [markdown]
# #### 날씨와 시간대별 평균자전거대여수에 대한 히트맵

# %%
# 날씨와 시간대별 평균자전거대여수에 대한 heatmap()

# %% [markdown]
# #### 근무여부(workingday)와 시간대별 평균자전거대여수에 대한 피봇테이블 생성

# %%
# 근무여부(working)와 시간대별 평균자전거대여수에 대한 피봇테이블
# Out:
# hours             0~2        3~5         6~8        9~11       12~14  \
# workingday
# 0           73.473441  14.494200   59.839080  255.705747  381.887356
# 1           20.459957  11.842634  291.070968  177.636559  192.291533
#
# hours            15~17       18~20       21~23
# workingday
# 0           360.158621  239.466667  120.898851
# 1           340.100750  364.710611  137.398714

# %% [markdown]
# #### 근무여부와 시간대별 평균자전거대여수에 대한 히트맵

# %%
# 근무여부(workingday)와 시간대별 평균자전거대여수에 대한 heatmap()

# %% [markdown]
# ## 4. 통계적 가설검정

# %% [markdown]
# ### 날씨(weather)에 따라 자전거 대여수(count)는 차이가 있는가?

# %% [markdown]
# ### 근무여부(workingday)에 따라 자전거 대여수(count)는 차이가 있는가?

# %% [markdown]
# ### 계절(season)에 따라 자전거대여수(count)는 차이가 있는가?
