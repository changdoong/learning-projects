# %%
import pandas as pd

playground_df = pd.read_csv('train.csv')
playground_df.head(10)
# Out:
#    id  age          job   marital  education default  balance housing loan  \
# 0   0   42   technician   married  secondary      no        7      no   no
# 1   1   38  blue-collar   married  secondary      no      514      no   no
# 2   2   36  blue-collar   married  secondary      no      602     yes   no
# 3   3   27      student    single  secondary      no       34     yes   no
# 4   4   26   technician   married  secondary      no      889     yes   no
# 5   5   24       admin.    single  secondary      no     1882     yes   no
# 6   6   39  blue-collar   married  secondary      no        0      no   no
# 7   7   50       admin.    single  secondary      no     1595      no   no
# 8   8   46  blue-collar   married    primary      no     1463      no   no
# 9   9   39   management  divorced   tertiary      no       25     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   cellular   25   aug       117         3     -1         0  unknown  0
# 1    unknown   18   jun       185         1     -1         0  unknown  0
# 2    unknown   14   may       111         2     -1         0  unknown  0
# 3    unknown   28   may        10         2     -1         0  unknown  0
# 4   cellular    3   feb       902         1     -1         0  unknown  1
# 5   cellular   20   apr      1010         3     -1         0  unknown  0
# 6  telephone   21   nov        90         1     -1         0  unknown  0
# 7  telephone   31   jul        49        25     -1         0  unknown  0
# 8   cellular    4   aug        50         1     -1         0  unknown  0
# 9   cellular    8   may       119         1     -1         0  unknown  0

# %% [markdown]
# ## 컬럼 설명
# - id             : id 번호
# - age            : 나이
# - job            : 직업
# - marital        : 결혼 여부
# - education      : 교육 수준
# - default        : 신용 불량 여부
# - balance        : 계좌 잔고
# - housing        : 주택 보유 여부
# - loan           : 대출 여부
# - contact        : 마지막 접촉 수단
# - day            : 마지막 접촉 일자
# - month          : 마지막 접촉 월
# - duration       : 마지막 접촉 통화 시간
# - campaign       : 이번 캠페인 동안 연락한 횟수
# - pdays          : 마지막 연락 후 경과일
# - previous       : 이전 캠페인에서 연락 횟수
# - poutcome       : 이전 캠페인의 결과
# - y              : 예금 가입 여부
#
# 입력변수  :
# 출력 변수 : y

# %%
playground_df.shape
# Out:
# (750000, 18)

# %%
playground_df['job'].value_counts()
# Out:
# job
# management       175541
# blue-collar      170498
# technician       138107
# admin.            81492
# services          64209
# retired           35185
# self-employed     19020
# entrepreneur      17718
# unemployed        17634
# housemaid         15912
# student           11767
# unknown            2917
# Name: count, dtype: int64

# %%
playground_df.isna().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
playground_df[['previous','campaign']].corr()
# Out:
#           previous  campaign
# previous  1.000000 -0.026707
# campaign -0.026707  1.000000

# %%
playground_df['poutcome'].value_counts().sort_values(ascending=False)
# Out:
# poutcome
# unknown    672450
# failure     45115
# success     17691
# other       14744
# Name: count, dtype: int64

# %%
playground_df['pdays'].value_counts()
# Out:
# pdays
# -1      672434
#  182      2515
#  92       2275
#  183      2074
#  181      1698
#          ...
#  735         1
#  611         1
#  714         1
#  54          1
#  376         1
# Name: count, Length: 596, dtype: int64

# %%
playground_df.sort_values(by='age', ascending=False)
# Out:
#             id  age      job   marital  education default  balance housing  \
# 283611  283611   95  retired   married  secondary      no     4984      no
# 557988  557988   95  retired  divorced    primary      no      852      no
# 551450  551450   95  retired   married  secondary      no     4657      no
# 164587  164587   94  retired  divorced    primary      no     1388      no
# 449210  449210   94  retired   married    unknown      no    12039      no
# ...        ...  ...      ...       ...        ...     ...      ...     ...
# 428100  428100   18  student    single  secondary      no      608      no
# 138704  138704   18  student    single  secondary      no     2143      no
# 453343  453343   18  student    single  secondary      no      608      no
# 445783  445783   18   admin.    single  secondary      no      696     yes
# 684519  684519   18  student    single    unknown      no      434      no
#
#        loan    contact  day month  duration  campaign  pdays  previous  \
# 283611   no  telephone   26   oct        88         1     -1         0
# 557988   no  telephone    1   apr       223         2     -1         0
# 551450   no  telephone   31   mar       466         1     -1         0
# 164587   no   cellular   12   nov       212         1     -1         0
# 449210   no  telephone   30   apr       516         4     -1         0
# ...     ...        ...  ...   ...       ...       ...    ...       ...
# 428100   no   cellular    1   jun       425         1     -1         0
# 138704   no   cellular    6   jul       265         3    178         5
# 453343   no   cellular    4   may       226         1     -1         0
# 445783  yes   cellular   13   may       474         2     -1         0
# 684519   no   cellular   21   apr       169         1     -1         0
#
#        poutcome  y
# 283611  unknown  0
# 557988  unknown  1
# 551450  unknown  1
# 164587  unknown  1
# 449210  unknown  1
# ...         ... ..
# 428100  unknown  1
# 138704  success  1
# 453343  unknown  1
# 445783  unknown  0
# 684519  unknown  1
#
# [750000 rows x 18 columns]

# %%
pd.DataFrame(playground_df[playground_df['pdays']==-1])
# Out:
#             id  age          job   marital  education default  balance  \
# 0            0   42   technician   married  secondary      no        7
# 1            1   38  blue-collar   married  secondary      no      514
# 2            2   36  blue-collar   married  secondary      no      602
# 3            3   27      student    single  secondary      no       34
# 4            4   26   technician   married  secondary      no      889
# ...        ...  ...          ...       ...        ...     ...      ...
# 749994  749994   31    housemaid    single  secondary      no      594
# 749995  749995   29     services    single  secondary      no     1282
# 749996  749996   69      retired  divorced   tertiary      no      631
# 749997  749997   50  blue-collar   married  secondary      no      217
# 749998  749998   32   technician   married  secondary      no     -274
#
#        housing loan   contact  day month  duration  campaign  pdays  previous  \
# 0           no   no  cellular   25   aug       117         3     -1         0
# 1           no   no   unknown   18   jun       185         1     -1         0
# 2          yes   no   unknown   14   may       111         2     -1         0
# 3          yes   no   unknown   28   may        10         2     -1         0
# 4          yes   no  cellular    3   feb       902         1     -1         0
# ...        ...  ...       ...  ...   ...       ...       ...    ...       ...
# 749994      no   no  cellular    4   feb       137         1     -1         0
# 749995      no  yes   unknown    4   jul      1006         2     -1         0
# 749996      no   no  cellular   19   aug        87         1     -1         0
# 749997     yes   no  cellular   17   apr       113         1     -1         0
# 749998      no   no  cellular   26   aug       108         6     -1         0
#
#        poutcome  y
# 0       unknown  0
# 1       unknown  0
# 2       unknown  0
# 3       unknown  0
# 4       unknown  1
# ...         ... ..
# 749994  unknown  0
# 749995  unknown  1
# 749996  unknown  0
# 749997  unknown  0
# 749998  unknown  0
#
# [672434 rows x 18 columns]

# %% [markdown]
# ## 카이제곱 검정 시행

# %%
chi = ['marital','education','housing','loan','contact','month','poutcome']

# %%
import scipy.stats as stats
from scipy.stats import chi2_contingency

for i in chi:
    ct = pd.crosstab(playground_df[i],playground_df['y'])
    chi2, p, _, _ = chi2_contingency(ct)
    print(f'== {i} vs y ==')
    print(ct)
    print(f'Chi2: {chi2:.3f}, p-value: {p:.8f}')
    print('\n')
# Out:
# == marital vs y ==
# y              0      1
# marital
# divorced   66105   8302
# married   431783  48976
# single    161624  33210
# Chi2: 6210.479, p-value: 0.00000000
#
#
# == education vs y ==
# y               0      1
# education
# primary     91241   8269
# secondary  359309  42374
# tertiary   190504  37004
# unknown     18458   2841
# Chi2: 6007.856, p-value: 0.00000000
#
#
# == housing vs y ==
# y             0      1
# housing
# no       279174  59538
# yes      380338  30950
# Chi2: 17691.305, p-value: 0.00000000
#
#
# == loan vs y ==
# y          0      1
# loan
# no    560281  84742
# yes    99231   5746
# Chi2: 4997.963, p-value: 0.00000000
#
#
# == contact vs y ==
# y               0      1
# contact
# cellular   410455  76200
# telephone   27379   4339
# unknown    221678   9949
# Chi2: 19179.184, p-value: 0.00000000
#
#
# == month vs y ==
# y           0      1
# month
# apr     31582   9737
# aug    114406  14453
# dec      1007   1062
# feb     29833   7778
# jan     16586   2351
# jul    100595  10052
# jun     83954   9716
# mar      2487   3315
# may    212113  16298
# nov     58808   7254
# oct      4694   4510
# sep      3447   3962
# Chi2: 52281.905, p-value: 0.00000000
#
#
# == poutcome vs y ==
# y              0      1
# poutcome
# failure    39124   5991
# other      12284   2460
# success     4175  13516
# unknown   603929  68521
# Chi2: 71606.061, p-value: 0.00000000

# %% [markdown]
# 데이터가 많아서 p-value값이 0이 나온 것 같긴 함
# 그래도 통계적 유의성만 본다면 범주형 컬럼중에 제외시켜야 할 컬럼은 없는 것 같음

# %%
map_YN = ['default','housing','loan']
for col in map_YN:
    playground_df[col] = playground_df[col].map({
    'no' : 0,
    'yes' : 1
})

# %%
playground_df
# Out:
#             id  age  default  balance  housing  loan  day  duration  campaign  \
# 0            0   42        0        7        0     0   25       117         3
# 1            1   38        0      514        0     0   18       185         1
# 2            2   36        0      602        1     0   14       111         2
# 3            3   27        0       34        1     0   28        10         2
# 4            4   26        0      889        1     0    3       902         1
# ...        ...  ...      ...      ...      ...   ...  ...       ...       ...
# 749995  749995   29        0     1282        0     1    4      1006         2
# 749996  749996   69        0      631        0     0   19        87         1
# 749997  749997   50        0      217        1     0   17       113         1
# 749998  749998   32        0     -274        0     0   26       108         6
# 749999  749999   42        0     1559        0     0    4       143         1
#
#         pdays  ...  month_jun  month_mar  month_may  month_nov  month_oct  \
# 0          -1  ...      False      False      False      False      False
# 1          -1  ...       True      False      False      False      False
# 2          -1  ...      False      False       True      False      False
# 3          -1  ...      False      False       True      False      False
# 4          -1  ...      False      False      False      False      False
# ...       ...  ...        ...        ...        ...        ...        ...
# 749995     -1  ...      False      False      False      False      False
# 749996     -1  ...      False      False      False      False      False
# 749997     -1  ...      False      False      False      False      False
# 749998     -1  ...      False      False      False      False      False
# 749999      1  ...      False      False      False      False      False
#
#         month_sep  poutcome_failure  poutcome_other  poutcome_success  \
# 0           False             False           False             False
# 1           False             False           False             False
# 2           False             False           False             False
# 3           False             False           False             False
# 4           False             False           False             False
# ...           ...               ...             ...               ...
# 749995      False             False           False             False
# 749996      False             False           False             False
# 749997      False             False           False             False
# 749998      False             False           False             False
# 749999      False              True           False             False
#
#         poutcome_unknown
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 749995              True
# 749996              True
# 749997              True
# 749998              True
# 749999             False
#
# [750000 rows x 50 columns]

# %%
playground_df = pd.get_dummies(columns=['job','marital','education','contact','month','poutcome'],data=playground_df)

# %%
playground_df.shape
# Out:
# (750000, 50)

# %%
X = playground_df.drop(columns='id')
y = playground_df['y']

# %%
from sklearn.model_selection import train_test_split

X_train,X_val,y_train,y_val = train_test_split(X,y, test_size=0.2)

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier()
models, predictions = clf.fit(X_train,X_val,y_train,y_val,verbose=0)
print(models.head(5))
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 72353, number of negative: 527647
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013956 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 965
# [LightGBM] [Info] Number of data points in the train set: 600000, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.120588 -> initscore=-1.986871
# [LightGBM] [Info] Start training from score -1.986871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                         Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier          1.00               1.00     1.00      1.00
# BaggingClassifier           1.00               1.00     1.00      1.00
# BernoulliNB                 1.00               1.00     1.00      1.00
# CalibratedClassifierCV      1.00               1.00     1.00      1.00
# DecisionTreeClassifier      1.00               1.00     1.00      1.00
#
#                         Time Taken
# Model
# AdaBoostClassifier            0.58
# BaggingClassifier             2.61
# BernoulliNB                   0.49
# CalibratedClassifierCV        3.60
# DecisionTreeClassifier        0.56

# %%
import optuna
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, StratifiedKFold

def objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 50, 500)
    learning_rate = trial.suggest_float("learning_rate", 0.01,1.0, log=True)
    max_depth = trial.suggest_int("max_depth", 1, 20)

    base_estimator = DecisionTreeClassifier(max_depth=max_depth)

    model = AdaBoostClassifier(
    estimator=base_estimator,
    n_estimators=n_estimators,
    learning_rate = learning_rate,
    random_state=2020158011
    )

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=2020158011)
    scores = cross_val_score(model,X_train,y_train, cv=cv, scoring='roc_auc')
    return scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print("best trial : ")
trial = study.best_trial
print(f" AUC score : {trial.value}")
print(f" Params   : {trial.params}")
# Out:
# [I 2025-08-07 12:08:50,554] A new study created in memory with name: no-name-28725d09-0441-48e3-b24a-7175fb2d9b9d
# [I 2025-08-07 12:08:54,365] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 401, 'learning_rate': 0.36433189253700227, 'max_depth': 2}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:08:58,187] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 251, 'learning_rate': 0.9261595533249957, 'max_depth': 10}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:01,985] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 75, 'learning_rate': 0.32020822508072316, 'max_depth': 11}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:05,860] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 85, 'learning_rate': 0.012716951833852345, 'max_depth': 11}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:09,634] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 355, 'learning_rate': 0.0683737522100042, 'max_depth': 9}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:13,561] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 214, 'learning_rate': 0.015542490174738136, 'max_depth': 6}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:17,359] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 436, 'learning_rate': 0.09050837239760362, 'max_depth': 18}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:21,083] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 465, 'learning_rate': 0.07948747198901047, 'max_depth': 11}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:24,892] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 263, 'learning_rate': 0.06756650582190304, 'max_depth': 1}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:28,713] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 302, 'learning_rate': 0.040528211884668174, 'max_depth': 5}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:32,563] Trial 10 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.317622389992917, 'max_depth': 1}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:36,417] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 170, 'learning_rate': 0.6637186284191525, 'max_depth': 16}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:40,312] Trial 12 finished with value: 1.0 and parameters: {'n_estimators': 362, 'learning_rate': 0.9744408857414303, 'max_depth': 15}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:44,020] Trial 13 finished with value: 1.0 and parameters: {'n_estimators': 377, 'learning_rate': 0.257134487605023, 'max_depth': 5}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:47,786] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 166, 'learning_rate': 0.5689123063944708, 'max_depth': 8}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:51,492] Trial 15 finished with value: 1.0 and parameters: {'n_estimators': 285, 'learning_rate': 0.17613885698073023, 'max_depth': 20}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:55,260] Trial 16 finished with value: 1.0 and parameters: {'n_estimators': 398, 'learning_rate': 0.9914460674863589, 'max_depth': 14}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:09:59,039] Trial 17 finished with value: 1.0 and parameters: {'n_estimators': 222, 'learning_rate': 0.49109088790390515, 'max_depth': 3}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:02,834] Trial 18 finished with value: 1.0 and parameters: {'n_estimators': 334, 'learning_rate': 0.13641058879173343, 'max_depth': 8}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:06,608] Trial 19 finished with value: 1.0 and parameters: {'n_estimators': 431, 'learning_rate': 0.42389604761579736, 'max_depth': 13}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:10,330] Trial 20 finished with value: 1.0 and parameters: {'n_estimators': 128, 'learning_rate': 0.20596717355041988, 'max_depth': 6}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:14,058] Trial 21 finished with value: 1.0 and parameters: {'n_estimators': 94, 'learning_rate': 0.35675744423314915, 'max_depth': 13}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:17,758] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 238, 'learning_rate': 0.6281326589528071, 'max_depth': 10}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:21,535] Trial 23 finished with value: 1.0 and parameters: {'n_estimators': 174, 'learning_rate': 0.13538282633989102, 'max_depth': 12}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:25,403] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 315, 'learning_rate': 0.28114942122882547, 'max_depth': 3}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:29,236] Trial 25 finished with value: 1.0 and parameters: {'n_estimators': 53, 'learning_rate': 0.7894065493067426, 'max_depth': 7}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:33,114] Trial 26 finished with value: 1.0 and parameters: {'n_estimators': 127, 'learning_rate': 0.45972803968387654, 'max_depth': 17}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:36,940] Trial 27 finished with value: 1.0 and parameters: {'n_estimators': 412, 'learning_rate': 0.04765634948159113, 'max_depth': 10}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:40,826] Trial 28 finished with value: 1.0 and parameters: {'n_estimators': 258, 'learning_rate': 0.22587419591839453, 'max_depth': 3}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:44,602] Trial 29 finished with value: 1.0 and parameters: {'n_estimators': 83, 'learning_rate': 0.13820452952686615, 'max_depth': 11}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:48,408] Trial 30 finished with value: 1.0 and parameters: {'n_estimators': 189, 'learning_rate': 0.7820522422954808, 'max_depth': 9}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:52,177] Trial 31 finished with value: 1.0 and parameters: {'n_estimators': 124, 'learning_rate': 0.020258691324195735, 'max_depth': 12}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:56,101] Trial 32 finished with value: 1.0 and parameters: {'n_estimators': 62, 'learning_rate': 0.011402249288807504, 'max_depth': 9}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:10:59,992] Trial 33 finished with value: 1.0 and parameters: {'n_estimators': 102, 'learning_rate': 0.0237137560837971, 'max_depth': 14}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:03,667] Trial 34 finished with value: 1.0 and parameters: {'n_estimators': 142, 'learning_rate': 0.03291927764850808, 'max_depth': 12}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:07,300] Trial 35 finished with value: 1.0 and parameters: {'n_estimators': 203, 'learning_rate': 0.10752730817983609, 'max_depth': 19}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:11,023] Trial 36 finished with value: 1.0 and parameters: {'n_estimators': 467, 'learning_rate': 0.06599658592303803, 'max_depth': 8}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:14,802] Trial 37 finished with value: 1.0 and parameters: {'n_estimators': 340, 'learning_rate': 0.38061089252827024, 'max_depth': 10}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:18,638] Trial 38 finished with value: 1.0 and parameters: {'n_estimators': 76, 'learning_rate': 0.17828286665384974, 'max_depth': 5}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:22,530] Trial 39 finished with value: 1.0 and parameters: {'n_estimators': 149, 'learning_rate': 0.013174404559541568, 'max_depth': 16}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:26,365] Trial 40 finished with value: 1.0 and parameters: {'n_estimators': 494, 'learning_rate': 0.09447338243129391, 'max_depth': 2}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:30,079] Trial 41 finished with value: 1.0 and parameters: {'n_estimators': 377, 'learning_rate': 0.0612141926148819, 'max_depth': 11}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:33,865] Trial 42 finished with value: 1.0 and parameters: {'n_estimators': 359, 'learning_rate': 0.02941789891544279, 'max_depth': 9}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:37,610] Trial 43 finished with value: 1.0 and parameters: {'n_estimators': 286, 'learning_rate': 0.050955091132797815, 'max_depth': 7}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:41,321] Trial 44 finished with value: 1.0 and parameters: {'n_estimators': 437, 'learning_rate': 0.01724685587408219, 'max_depth': 13}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:45,158] Trial 45 finished with value: 1.0 and parameters: {'n_estimators': 393, 'learning_rate': 0.28147086220195566, 'max_depth': 6}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:48,998] Trial 46 finished with value: 1.0 and parameters: {'n_estimators': 305, 'learning_rate': 0.5550521694528814, 'max_depth': 14}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:52,858] Trial 47 finished with value: 1.0 and parameters: {'n_estimators': 255, 'learning_rate': 0.07844690631294977, 'max_depth': 1}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:11:56,562] Trial 48 finished with value: 1.0 and parameters: {'n_estimators': 330, 'learning_rate': 0.7836319094290644, 'max_depth': 11}. Best is trial 0 with value: 1.0.
# [I 2025-08-07 12:12:00,346] Trial 49 finished with value: 1.0 and parameters: {'n_estimators': 109, 'learning_rate': 0.33392681370316935, 'max_depth': 7}. Best is trial 0 with value: 1.0.
# best trial :
#  AUC score : 1.0
#  Params   : {'n_estimators': 401, 'learning_rate': 0.36433189253700227, 'max_depth': 2}
