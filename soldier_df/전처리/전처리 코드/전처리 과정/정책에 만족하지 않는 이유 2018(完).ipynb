# %%
import pandas as pd

# %%
# 파일 불러오기
df = pd.read_csv('정책에 불만족하는 이유 2018.csv')

# %%
df
# Out:
#       C1_NM  Unnamed: 0              C2_NM    DT
# 0        전체           0       현행 지원 범위의 미흡  40.7
# 1        전체           1  국가보훈부의 정책적 기능의 한계   9.0
# 2        전체           2  각종 교육 홍보 상담 여건 미비   4.8
# 3        전체           3        현행 지원수준의 미흡  45.4
# 4        전체           4                 기타   0.1
# ..      ...         ...                ...   ...
# 80  보훈보상대상자          80       현행 지원 범위의 미흡  44.9
# 81  보훈보상대상자          81  국가보훈부의 정책적 기능의 한계  12.6
# 82  보훈보상대상자          82  각종 교육 홍보 상담 여건 미비   4.6
# 83  보훈보상대상자          83        현행 지원수준의 미흡  35.2
# 84  보훈보상대상자          84                 기타   2.7
#
# [85 rows x 4 columns]

# %%
# 컬럼 삭제
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#                      C2_NM    DT    연도
# C1_NM
# 전체            현행 지원 범위의 미흡  40.7  2018
# 전체       국가보훈부의 정책적 기능의 한계   9.0  2018
# 전체       각종 교육 홍보 상담 여건 미비   4.8  2018
# 전체             현행 지원수준의 미흡  45.4  2018
# 전체                      기타   0.1  2018
# ...                    ...   ...   ...
# 보훈보상대상자       현행 지원 범위의 미흡  44.9  2018
# 보훈보상대상자  국가보훈부의 정책적 기능의 한계  12.6  2018
# 보훈보상대상자  각종 교육 홍보 상담 여건 미비   4.6  2018
# 보훈보상대상자        현행 지원수준의 미흡  35.2  2018
# 보훈보상대상자                 기타   2.7  2018
#
# [85 rows x 3 columns]

# %%
# 인덱스 설정
df.set_index('C1_NM', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df.set_index('C1_NM', inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:6122, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6119                 missing.append(col)
#    6121 if missing:
# -> 6122     raise KeyError(f"None of {missing} are in the columns")
#    6124 if inplace:
#    6125     frame = self
#
# KeyError: "None of ['C1_NM'] are in the columns"

# %%
df
# Out:
#                      C2_NM    DT    연도
# C1_NM
# 전체            현행 지원 범위의 미흡  40.7  2018
# 전체       국가보훈부의 정책적 기능의 한계   9.0  2018
# 전체       각종 교육 홍보 상담 여건 미비   4.8  2018
# 전체             현행 지원수준의 미흡  45.4  2018
# 전체                      기타   0.1  2018
# ...                    ...   ...   ...
# 보훈보상대상자       현행 지원 범위의 미흡  44.9  2018
# 보훈보상대상자  국가보훈부의 정책적 기능의 한계  12.6  2018
# 보훈보상대상자  각종 교육 홍보 상담 여건 미비   4.6  2018
# 보훈보상대상자        현행 지원수준의 미흡  35.2  2018
# 보훈보상대상자                 기타   2.7  2018
#
# [85 rows x 3 columns]

# %%
# 2018년 연도 컬럼 추가
df['연도'] = '2018'

# %%
df
# Out:
#                      C2_NM    DT    연도
# C1_NM
# 전체            현행 지원 범위의 미흡  40.7  2018
# 전체       국가보훈부의 정책적 기능의 한계   9.0  2018
# 전체       각종 교육 홍보 상담 여건 미비   4.8  2018
# 전체             현행 지원수준의 미흡  45.4  2018
# 전체                      기타   0.1  2018
# ...                    ...   ...   ...
# 보훈보상대상자       현행 지원 범위의 미흡  44.9  2018
# 보훈보상대상자  국가보훈부의 정책적 기능의 한계  12.6  2018
# 보훈보상대상자  각종 교육 홍보 상담 여건 미비   4.6  2018
# 보훈보상대상자        현행 지원수준의 미흡  35.2  2018
# 보훈보상대상자                 기타   2.7  2018
#
# [85 rows x 3 columns]

# %%
# csv 파일로 저장
df.to_csv('정책에 만족하지 않는 이유 2018.csv')
