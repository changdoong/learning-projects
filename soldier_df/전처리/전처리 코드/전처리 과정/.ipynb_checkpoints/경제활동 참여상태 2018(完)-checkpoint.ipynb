# %%
import pandas as pd
df = pd.read_csv('경제활동 참여 상태 2018.csv')
df
# Out:
#     Unnamed: 0 C1_OBJ_NM                    C2_NM    DT      C1_NM UNIT_NM  \
# 0            0       특성별               취업자(일을 한다)  34.5         전체       %
# 1            1       특성별     향후 구직의사 있음(학생 구직자 등)   5.0         전체       %
# 2            2       특성별  향후 구직의사 없음(연로자 구직단념자 등)  60.5         전체       %
# 3            3       특성별               취업자(일을 한다)  39.3         남성       %
# 4            4       특성별     향후 구직의사 있음(학생 구직자 등)   5.4         남성       %
# 5            5       특성별  향후 구직의사 없음(연로자 구직단념자 등)  55.3         남성       %
# 6            6       특성별               취업자(일을 한다)  17.6         여성       %
# 7            7       특성별     향후 구직의사 있음(학생 구직자 등)   3.3         여성       %
# 8            8       특성별  향후 구직의사 없음(연로자 구직단념자 등)  79.1         여성       %
# 9            9       특성별               취업자(일을 한다)  83.8     30대 이하       %
# 10          10       특성별     향후 구직의사 있음(학생 구직자 등)  12.0     30대 이하       %
# ...

# %%
df = df.drop(columns=['Unnamed: 0','C1_OBJ_NM','UNIT_NM','ITM_NM','C2_OBJ_NM','TBL_NM'])
df
# Out:
#                       C2_NM    DT      C1_NM
# 0                취업자(일을 한다)  34.5         전체
# 1      향후 구직의사 있음(학생 구직자 등)   5.0         전체
# 2   향후 구직의사 없음(연로자 구직단념자 등)  60.5         전체
# 3                취업자(일을 한다)  39.3         남성
# 4      향후 구직의사 있음(학생 구직자 등)   5.4         남성
# 5   향후 구직의사 없음(연로자 구직단념자 등)  55.3         남성
# 6                취업자(일을 한다)  17.6         여성
# 7      향후 구직의사 있음(학생 구직자 등)   3.3         여성
# 8   향후 구직의사 없음(연로자 구직단념자 등)  79.1         여성
# 9                취업자(일을 한다)  83.8     30대 이하
# 10     향후 구직의사 있음(학생 구직자 등)  12.0     30대 이하
# 11  향후 구직의사 없음(연로자 구직단념자 등)   4.2     30대 이하
# 12               취업자(일을 한다)  86.3        40대
# 13     향후 구직의사 있음(학생 구직자 등)   7.2        40대
# 14  향후 구직의사 없음(연로자 구직단념자 등)   6.6        40대
# 15               취업자(일을 한다)  78.0        50대
# 16     향후 구직의사 있음(학생 구직자 등)   8.0        50대
# 17  향후 구직의사 없음(연로자 구직단념자 등)  14.0        50대
# 18               취업자(일을 한다)  48.2        60대
# 19     향후 구직의사 있음(학생 구직자 등)   7.9        60대
# ...

# %%
df['연도'] = '2018'
df
# Out:
#                       C2_NM    DT      C1_NM    연도
# 0                취업자(일을 한다)  34.5         전체  2018
# 1      향후 구직의사 있음(학생 구직자 등)   5.0         전체  2018
# 2   향후 구직의사 없음(연로자 구직단념자 등)  60.5         전체  2018
# 3                취업자(일을 한다)  39.3         남성  2018
# 4      향후 구직의사 있음(학생 구직자 등)   5.4         남성  2018
# 5   향후 구직의사 없음(연로자 구직단념자 등)  55.3         남성  2018
# 6                취업자(일을 한다)  17.6         여성  2018
# 7      향후 구직의사 있음(학생 구직자 등)   3.3         여성  2018
# 8   향후 구직의사 없음(연로자 구직단념자 등)  79.1         여성  2018
# 9                취업자(일을 한다)  83.8     30대 이하  2018
# 10     향후 구직의사 있음(학생 구직자 등)  12.0     30대 이하  2018
# 11  향후 구직의사 없음(연로자 구직단념자 등)   4.2     30대 이하  2018
# 12               취업자(일을 한다)  86.3        40대  2018
# 13     향후 구직의사 있음(학생 구직자 등)   7.2        40대  2018
# 14  향후 구직의사 없음(연로자 구직단념자 등)   6.6        40대  2018
# 15               취업자(일을 한다)  78.0        50대  2018
# 16     향후 구직의사 있음(학생 구직자 등)   8.0        50대  2018
# ...

# %%
df = df.rename(columns={
    "C1_NM": "구분",
    "C2_NM": "취업여부",
    "DT": "비율",
    "연도": "연도"
})
df
# Out:
#                        취업여부    비율         구분    연도
# 0                취업자(일을 한다)  34.5         전체  2018
# 1      향후 구직의사 있음(학생 구직자 등)   5.0         전체  2018
# 2   향후 구직의사 없음(연로자 구직단념자 등)  60.5         전체  2018
# 3                취업자(일을 한다)  39.3         남성  2018
# 4      향후 구직의사 있음(학생 구직자 등)   5.4         남성  2018
# 5   향후 구직의사 없음(연로자 구직단념자 등)  55.3         남성  2018
# 6                취업자(일을 한다)  17.6         여성  2018
# 7      향후 구직의사 있음(학생 구직자 등)   3.3         여성  2018
# 8   향후 구직의사 없음(연로자 구직단념자 등)  79.1         여성  2018
# 9                취업자(일을 한다)  83.8     30대 이하  2018
# 10     향후 구직의사 있음(학생 구직자 등)  12.0     30대 이하  2018
# 11  향후 구직의사 없음(연로자 구직단념자 등)   4.2     30대 이하  2018
# 12               취업자(일을 한다)  86.3        40대  2018
# 13     향후 구직의사 있음(학생 구직자 등)   7.2        40대  2018
# 14  향후 구직의사 없음(연로자 구직단념자 등)   6.6        40대  2018
# 15               취업자(일을 한다)  78.0        50대  2018
# 16     향후 구직의사 있음(학생 구직자 등)   8.0        50대  2018
# ...

# %%
df.to_csv('경제활동 참여 상태 2018.csv', index=False)
