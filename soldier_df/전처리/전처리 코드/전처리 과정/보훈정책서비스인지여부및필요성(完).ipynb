# %%
import pandas as pd

# %%
# 파일 불러오기
data1=pd.read_csv('보훈정책서비스인지여부및필요성 2018_전처리.csv')
data1
# Out:
#     Unnamed: 0     유공자 구분         지원 항목  알고 있음  모르고 있음  (사회적) 필요성
# 0            0  국가유공자(본인)          교육지원   79.2    20.8       4.40
# 1            1  국가유공자(본인)          대부지원   71.2    28.8       4.33
# 2            2  국가유공자(본인)         보철구지원   61.8    38.2       4.24
# 3            3  국가유공자(본인)    보훈상담센터 서비스   50.1    49.9       4.10
# 4            4  국가유공자(본인)         사망시지원   94.6     5.4       4.42
# 5            5  국가유공자(본인)       수송시설 지원   77.6    22.4       4.29
# 6            6  국가유공자(본인)          양로보호   62.0    38.0       4.31
# 7            7  국가유공자(본인)          의료지원   94.7     5.3       4.61
# 8            8  국가유공자(본인)  이동보훈복지서비스 지원   48.6    51.4       4.24
# 9            9  국가유공자(본인)        이용료 감면   87.1    12.9       4.20
# 10          10  국가유공자(본인)          취업지원   74.6    25.4       4.35
# 11          11  국가유공자(본인)        휴양시설이용   53.4    46.6       4.02
# 12          12  국가유공자(유족)          교육지원   45.7    54.3       4.17
# ...

# %%
# 파일 불러오기
data2=pd.read_csv('보훈정책서비스인지여부및필요성 2021_전처리.csv')
data2
# Out:
#     Unnamed: 0     유공자 구분    지원 항목  알고 있음  모르고 있음
# 0            0  국가유공자(본인)     교육지원   63.9    36.1
# 1            1  국가유공자(본인)     대부지원   58.3    41.7
# 2            2  국가유공자(본인)    보철구지원   49.1    50.9
# 3            3  국가유공자(본인)    보훈급여금   96.8     3.2
# 4            4  국가유공자(본인)    사망시지원   97.3     2.7
# ..         ...        ...      ...    ...     ...
# 60          60    특수임무유공자     의료지원   77.5    22.5
# 61          61    특수임무유공자   이용료 감면   36.7    63.3
# 62          62    특수임무유공자  재가복지서비스   29.7    70.3
# 63          63    특수임무유공자     취업지원   51.6    48.4
# 64          64    특수임무유공자   휴양시설이용   40.0    60.0
#
# [65 rows x 5 columns]

# %%
# 파일 불러오기
data3=pd.read_csv('보훈정책서비스인지여부및필요성 2024_전처리.csv')
data3
# Out:
#     Unnamed: 0     유공자 구분           지원 항목  알고 있음  모르고 있음
# 0            0  국가유공자(본인)            교육지원   53.4    46.6
# 1            1  국가유공자(본인)            대부지원   46.9    53.1
# 2            2  국가유공자(본인)           보철구지원   42.4    57.6
# 3            3  국가유공자(본인)           보훈급여금   94.7     5.3
# 4            4  국가유공자(본인)           사망시지원   73.5    26.5
# ..         ...        ...             ...    ...     ...
# 65          65    특수임무유공자          이용료 감면   62.4    37.6
# 66          66    특수임무유공자         재가복지서비스   37.7    62.3
# 67          67    특수임무유공자  제대군인지원센터 전직 지원   41.0    59.0
# 68          68    특수임무유공자            취업지원   44.4    55.6
# 69          69    특수임무유공자          휴양시설이용   41.5    58.5
#
# [70 rows x 5 columns]

# %%
# 데이터 병합
total=pd.concat([data1, data2, data3])
total
# Out:
#     Unnamed: 0     유공자 구분           지원 항목  알고 있음  모르고 있음  (사회적) 필요성
# 0            0  국가유공자(본인)            교육지원   79.2    20.8       4.40
# 1            1  국가유공자(본인)            대부지원   71.2    28.8       4.33
# 2            2  국가유공자(본인)           보철구지원   61.8    38.2       4.24
# 3            3  국가유공자(본인)      보훈상담센터 서비스   50.1    49.9       4.10
# 4            4  국가유공자(본인)           사망시지원   94.6     5.4       4.42
# ..         ...        ...             ...    ...     ...        ...
# 65          65    특수임무유공자          이용료 감면   62.4    37.6        NaN
# 66          66    특수임무유공자         재가복지서비스   37.7    62.3        NaN
# 67          67    특수임무유공자  제대군인지원센터 전직 지원   41.0    59.0        NaN
# 68          68    특수임무유공자            취업지원   44.4    55.6        NaN
# 69          69    특수임무유공자          휴양시설이용   41.5    58.5        NaN
#
# [195 rows x 6 columns]
