# %%
import pandas as pd

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
train_df.head()
# Out:
#    id road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0   0     urban          2       0.06           35  daylight   rainy
# 1   1     urban          4       0.99           35  daylight   clear
# 2   2     rural          4       0.63           70       dim   clear
# 3   3   highway          4       0.07           35       dim   rainy
# 4   4     rural          1       0.58           60  daylight   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0               False         True   afternoon    False           True
# 1                True        False     evening     True           True
# 2               False         True     morning     True          False
# 3                True         True     morning    False          False
# 4               False        False     evening     True          False
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56

# %% [markdown]
# 불필요 컬럼
#
#
#
#
# 목표 피쳐 : accident_risk

# %%
train_df.shape
# Out:
# (517754, 14)

# %%
train_df.isna().sum()
# Out:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# accident_risk             0
# dtype: int64

# %%
train_df.nunique()
# Out:
# id                        517754
# road_type                      3
# num_lanes                      4
# curvature                    261
# speed_limit                    5
# lighting                       3
# weather                        3
# road_signs_present             2
# public_road                    2
# time_of_day                    3
# holiday                        2
# school_season                  2
# num_reported_accidents         8
# accident_risk                 98
# dtype: int64

# %%
train_df[['curvature','speed_limit','num_reported_accidents']].describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_1fcdf_row0_col0, #T_1fcdf_row0_col1, #T_1fcdf_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1fcdf_row1_col0, #T_1fcdf_row1_col1, #T_1fcdf_row1_col2, #T_1fcdf_row2_col0, #T_1fcdf_row2_col1, #T_1fcdf_row2_col2, #T_1fcdf_row3_col0, #T_1fcdf_row3_col1, #T_1fcdf_row3_col2, #T_1fcdf_row4_col0, #T_1fcdf_row4_col1, #T_1fcdf_row4_col2, #T_1fcdf_row5_col0, #T_1fcdf_row5_col1, #T_1fcdf_row5_col2, #T_1fcdf_row6_col0, #T_1fcdf_row6_col1, #T_1fcdf_row6_col2, #T_1fcdf_row7_col0, #T_1fcdf_row7_col1, #T_1fcdf_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_1fcdf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fcdf_level0_col0" class="col_heading level0 col0" >curvature</th>
#       <th id="T_1fcdf_level0_col1" class="col_heading level0 col1" >speed_limit</th>
#       <th id="T_1fcdf_level0_col2" class="col_heading level0 col2" >num_reported_accidents</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fcdf_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_1fcdf_row0_col0" class="data row0 col0" >517754.000000</td>
#       <td id="T_1fcdf_row0_col1" class="data row0 col1" >517754.000000</td>
#       <td id="T_1fcdf_row0_col2" class="data row0 col2" >517754.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fcdf_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_1fcdf_row1_col0" class="data row1 col0" >0.488719</td>
#       <td id="T_1fcdf_row1_col1" class="data row1 col1" >46.112575</td>
#       <td id="T_1fcdf_row1_col2" class="data row1 col2" >1.187970</td>
#     </tr>
#     <tr>
#       <th id="T_1fcdf_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_1fcdf_row2_col0" class="data row2 col0" >0.272563</td>
#       <td id="T_1fcdf_row2_col1" class="data row2 col1" >15.788521</td>
#       <td id="T_1fcdf_row2_col2" class="data row2 col2" >0.895961</td>
#     </tr>
#     <tr>
#       <th id="T_1fcdf_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_1fcdf_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_1fcdf_row3_col1" class="data row3 col1" >25.000000</td>
#       <td id="T_1fcdf_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fcdf_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_1fcdf_row4_col0" class="data row4 col0" >0.260000</td>
#       <td id="T_1fcdf_row4_col1" class="data row4 col1" >35.000000</td>
#       <td id="T_1fcdf_row4_col2" class="data row4 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fcdf_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_1fcdf_row5_col0" class="data row5 col0" >0.510000</td>
#       <td id="T_1fcdf_row5_col1" class="data row5 col1" >45.000000</td>
#       <td id="T_1fcdf_row5_col2" class="data row5 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fcdf_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_1fcdf_row6_col0" class="data row6 col0" >0.710000</td>
#       <td id="T_1fcdf_row6_col1" class="data row6 col1" >60.000000</td>
#       <td id="T_1fcdf_row6_col2" class="data row6 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fcdf_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_1fcdf_row7_col0" class="data row7 col0" >1.000000</td>
#       <td id="T_1fcdf_row7_col1" class="data row7 col1" >70.000000</td>
#       <td id="T_1fcdf_row7_col2" class="data row7 col2" >7.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_df['num_reported_accidents'].unique()
# Out:
# array([1, 0, 2, 3, 4, 5, 6, 7])

# %%
train_df['lighting'].unique()
# Out:
# array(['daylight', 'dim', 'night'], dtype=object)

# %%
train_df.drop(columns='id',inplace=True)
test_df.drop(columns='id',inplace=True)

# %%
train_df.head()
# Out:
#   road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0     urban          2       0.06           35  daylight   rainy
# 1     urban          4       0.99           35  daylight   clear
# 2     rural          4       0.63           70       dim   clear
# 3   highway          4       0.07           35       dim   rainy
# 4     rural          1       0.58           60  daylight   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0               False         True   afternoon    False           True
# 1                True        False     evening     True           True
# 2               False         True     morning     True          False
# 3                True         True     morning    False          False
# 4               False        False     evening     True          False
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56

# %%
test_df.head()
# Out:
#   road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0   highway          2       0.34           45     night   clear
# 1     urban          3       0.04           45       dim   foggy
# 2     urban          2       0.59           35       dim   clear
# 3     rural          4       0.95           35  daylight   rainy
# 4   highway          2       0.86           35  daylight   clear
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0                True         True   afternoon     True           True
# 1                True        False   afternoon     True          False
# 2                True        False   afternoon     True           True
# 3               False        False   afternoon    False          False
# 4                True        False     evening    False           True
#
#    num_reported_accidents
# 0                       1
# 1                       0
# 2                       1
# 3                       2
# 4                       3

# %%
train_df['road_type'].unique()
# Out:
# array(['urban', 'rural', 'highway'], dtype=object)

# %%
train_df
# Out:
#        road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0          urban          2       0.06           35  daylight   rainy
# 1          urban          4       0.99           35  daylight   clear
# 2          rural          4       0.63           70       dim   clear
# 3        highway          4       0.07           35       dim   rainy
# 4          rural          1       0.58           60  daylight   foggy
# ...          ...        ...        ...          ...       ...     ...
# 517749   highway          4       0.10           70  daylight   foggy
# 517750     rural          4       0.47           35  daylight   rainy
# 517751     urban          4       0.62           25  daylight   foggy
# 517752   highway          3       0.63           25     night   clear
# 517753   highway          2       0.31           45       dim   rainy
#
#         road_signs_present  public_road time_of_day  holiday  school_season  \
# 0                    False         True   afternoon    False           True
# 1                     True        False     evening     True           True
# 2                    False         True     morning     True          False
# 3                     True         True     morning    False          False
# 4                    False        False     evening     True          False
# ...                    ...          ...         ...      ...            ...
# 517749                True         True   afternoon    False          False
# 517750                True         True     morning    False          False
# 517751               False        False   afternoon    False           True
# 517752                True        False   afternoon     True           True
# 517753               False         True   afternoon     True           True
#
#         num_reported_accidents  accident_risk
# 0                            1           0.13
# 1                            0           0.35
# 2                            2           0.30
# 3                            1           0.21
# 4                            1           0.56
# ...                        ...            ...
# 517749                       2           0.32
# 517750                       1           0.26
# 517751                       0           0.19
# 517752                       3           0.51
# 517753                       2           0.22
#
# [517754 rows x 13 columns]

# %%
train_df['weather'].unique()
# Out:
# array(['rainy', 'clear', 'foggy'], dtype=object)

# %%
map_col = {'urban' : 0,
           'rural' : 1,
           'highway' : 2
          }

# %%
train_df['road_type'] = train_df['road_type'].map(map_col)

# %%
train_df['lighting'].unique()
# Out:
# array(['daylight', 'dim', 'night'], dtype=object)

# %%
map_col2 = {'daylight' : 0,
            'dim' : 1,
            'night' : 2
           }

# %%
train_df['lighting'] = train_df['lighting'].map(map_col2)

# %%
train_df.head()
# Out:
#    road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0          0          2       0.06           35         0   rainy
# 1          0          4       0.99           35         0   clear
# 2          1          4       0.63           70         1   clear
# 3          2          4       0.07           35         1   rainy
# 4          1          1       0.58           60         0   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0               False         True   afternoon    False           True
# 1                True        False     evening     True           True
# 2               False         True     morning     True          False
# 3                True         True     morning    False          False
# 4               False        False     evening     True          False
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# 2                       2           0.30
# 3                       1           0.21
# 4                       1           0.56

# %%
train_df['weather'].unique()
# Out:
# array(['rainy', 'clear', 'foggy'], dtype=object)

# %%
map_col3 = {'rainy' : 0,
            'clear' : 1,
            'foggy' : 2                                                                                                                                                                                                                                                                                                                   
           }
train_df['weather'] = train_df['weather'].map(map_col3)

# %%
train_df['time_of_day'].unique()
# Out:
# array(['afternoon', 'evening', 'morning'], dtype=object)

# %%
map_col4 = {'afternoon' :  0,
            'evening' : 1,
            'morning' : 2
           }
train_df['time_of_day'] = train_df['time_of_day'].map(map_col4)

# %%
train_df.nunique()
# Out:
# road_type                   3
# num_lanes                   4
# curvature                 261
# speed_limit                 5
# lighting                    3
# weather                     3
# road_signs_present          2
# public_road                 2
# time_of_day                 3
# holiday                     2
# school_season               2
# num_reported_accidents      8
# accident_risk              98
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(data=train_df.iloc[:,:-1], diag_kind='kde')
plt.show()

# %%
X = train_df.drop(columns='accident_risk')
y = train_df['accident_risk']

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 X_train.head()
#
# NameError: name 'X_train' is not defined

# %%
# from lazypredict.Supervised import LazyRegressor
# reg = LazyRegressor(verbose=0)
# models, predictions = reg.fit(X_train[:30000], X_val[:30000], y_train[:30000], y_val[:30000])

# print(models)
